# %% [markdown]
# ## Reminder
# Please use Python 3.10 or Python 3.9 to run the code. Otherwise the pd.json_normalize function may not work
#
# ## Data collection idea
# * Use "Board" dataset as a bridge to link both "Sprint" and "Issue" URL and data table.
# * For spint and issues table, attach create a new column and store board id in it, so that we can know which board does the data comes from.
#
# ### Steps:
# #### Board:
# 1. Retrieve board from API URL: {Base URL of your project}/rest/agile/1.0/board?projectKeyOrId={projectKey}
# * Base URL: check the excel file on OneDrive
# * ProjectKey: Search the project name on corresponding platform (RedHat or Apache) -> Under the "Project" category
# 2. Request data by using GET method and get the json output.
# 3. Transform data from JSON format to the pandas dataframe.
# 4. Filter the board type (type == 'scrum') and reset the index
# 5. Store board_id for future analysis
# 6. Save as csv file so that we don't have to rerun the code every time.
#
# #### Sprint:
# 1. Loop pre-stored board_id to get all sprint and store them into an empty list (as computation cost of expand a cost is much smaller than expand a pandas dataframe).
# 2. Normalize the list and we will get a dataframe (called df_initalResult) whose records are all nested.
# 3. For each row, we want to flatten the data into a normal data record type. Therefore, we create a new empty dataframe (df_finalResult) first then loop through the "df_initalResult" by using its index and save each records in a temp dataframe (df_temp). Then concat df_finalResult and df_temp, after which, we can get a complete datasets that contains all records.
# 4. Save as csv file.
#
# #### Issues:
# 1. Similar as Sprint method. The thing is that we only want the issues that have story points, which is stored in customer fields (check column name in excel file). Therefore, after we getting all issues, we need to filter out the issues that have story points.
# 2. Save as csv file.

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import base64
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Your Project Name

# %%
#For RedHat, just replace your token and keep string "Bearer"
auth = "Bearer MTgyMzA3NDEyMjM4OsoPSl9xCrK2UckJ1KRM0wzOefbD"

# %% [markdown]
# ### Board

# %%
# Replace BaseURL and project key with your own project
board_url = 'https://issues.apache.org/jira/rest/agile/1.0/board?projectKeyOrId=AURORA'

headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}

payload = {
   "maxResults":50 #100, 20
}

# Request data by using GET method and directly get the json output
board = requests.request("GET",board_url,headers=headers, params=payload).json()

# As we only intreseted in the "values" in the board, so we only normalize the board['values']
board_df = pd.json_normalize(board['values'])

# Filter the scrum board type and maintain the pd dataframe formate
board_df = board_df[board_df['type']=='scrum']

# Reset the index for the future convience.
board_df = board_df.reset_index()

# Store the board id into variable board_id
board_id = board_df['id']

#Save the df as csv file. Use your project name to define the file name
board_df.to_csv('Aurora_board.csv')

# %% [markdown]
# #### Sprint

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}


payload_sprint = {
'maxResults':2000  #Retrieve at most 2000 records, can be modified based on your own project
}

list1 = [] 

# Loop through the required board, and store the records into the empty list1
for i in board_id:
   sprint_url = 'https://issues.apache.org/jira/rest/agile/1.0/board/' + f'{i}' + '/sprint'
   sprint = requests.request("GET",sprint_url ,headers=headers, params=payload_sprint).json()
   try:
      list1.append(sprint['values'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
sprint_df = pd.json_normalize(list1)
sprint_df.head()
# Out:
#                                                   0   \
# 0  {'id': 7, 'self': 'https://issues.apache.org/j...
#
#                                                   1   \
# 0  {'id': 11, 'self': 'https://issues.apache.org/...
#
#                                                   2   \
# 0  {'id': 13, 'self': 'https://issues.apache.org/...
#
#                                                   3   \
# 0  {'id': 15, 'self': 'https://issues.apache.org/...
#
#                                                   4   \
# 0  {'id': 23, 'self': 'https://issues.apache.org/...
#
#                                                   5   \
# 0  {'id': 26, 'self': 'https://issues.apache.org/...
#
#                                                   6   \
# 0  {'id': 39, 'self': 'https://issues.apache.org/...
#
#                                                   7   \
# 0  {'id': 42, 'self': 'https://issues.apache.org/...
#
#                                                   8   \
# 0  {'id': 46, 'self': 'https://issues.apache.org/...
#
#                                                   9   ...  \
# 0  {'id': 52, 'self': 'https://issues.apache.org/...  ...
#
#                                                   30  \
# 0  {'id': 190, 'self': 'https://issues.apache.org...
#
#                                                   31  \
# 0  {'id': 191, 'self': 'https://issues.apache.org...
#
#                                                   32  \
# 0  {'id': 197, 'self': 'https://issues.apache.org...
#
#                                                   33  \
# 0  {'id': 203, 'self': 'https://issues.apache.org...
#
#                                                   34  \
# 0  {'id': 211, 'self': 'https://issues.apache.org...
#
#                                                   35  \
# 0  {'id': 212, 'self': 'https://issues.apache.org...
#
#                                                   36  \
# 0  {'id': 220, 'self': 'https://issues.apache.org...
#
#                                                   37  \
# 0  {'id': 223, 'self': 'https://issues.apache.org...
#
#                                                   38  \
# 0  {'id': 243, 'self': 'https://issues.apache.org...
#
#                                                   39
# 0  {'id': 250, 'self': 'https://issues.apache.org...
#
# [1 rows x 40 columns]

# %%
#Create an empty dataframe
sprint_result = pd.DataFrame()
sprint_result.head()

# sprint_df.index is the row number. For each row, we need to flatten the records and store them into a dataframe. Our goal is to flatten all these record and generate a single dataframe.
for i in sprint_df.index:
   # Flatten records in a row based on row index
   sprint_df_1 = sprint_df.iloc[i].apply(pd.Series) 
   # Attach corresponding board_id
   sprint_df_1['board_id'] = board_df['id'][i]
   # Create a list called "frame" to tell python we want to contact two dataframs together -- sprint_result and sprint_df_1
   frame = [sprint_result, sprint_df_1]
   #Contact two dataframes
   sprint_result = pd.concat(frame)

# %%
# Filter the sprint that totally empty
sprint_result = sprint_result[sprint_result['id'].notna()]
sprint_result.head()
# Out:
#    id                                               self   state         name  \
# 0   7  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 1
# 1  11  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 2
# 2  13  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 3
# 3  15  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 3
# 4  23  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q3 Sprint 1
#
#                   startDate                   endDate  \
# 0  2014-05-12T21:26:22.322Z  2014-05-17T00:00:00.000Z
# 1  2014-05-19T19:00:10.084Z  2014-05-24T00:00:00.000Z
# 2  2014-05-31T00:00:30.253Z  2014-06-12T00:00:00.000Z
# 3  2014-06-02T19:00:46.818Z  2014-06-07T00:00:00.000Z
# 4  2014-07-15T05:43:31.920Z  2014-07-19T00:00:00.000Z
#
#                completeDate             activatedDate  originBoardId  board_id
# 0  2014-05-19T19:11:51.658Z  2014-05-12T21:26:22.322Z             37        37
# 1  2014-06-02T19:39:27.844Z  2014-05-19T19:00:10.084Z             37        37
# 2  2014-06-13T23:05:05.267Z  2014-05-31T00:00:30.253Z             35        37
# 3  2014-07-14T16:51:27.048Z  2014-06-02T19:00:46.818Z             37        37
# 4  2014-07-25T16:28:42.789Z  2014-07-15T05:43:31.920Z             37        37

# %%
# Reset the index
sprint_result = sprint_result.reset_index()
# Drop the origianl index column
sprint_result = sprint_result.drop(columns=['index'])
sprint_result.head()
# Out:
#    id                                               self   state         name  \
# 0   7  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 1
# 1  11  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 2
# 2  13  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 3
# 3  15  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q2 Sprint 3
# 4  23  https://issues.apache.org/jira/rest/agile/1.0/...  closed  Q3 Sprint 1
#
#                   startDate                   endDate  \
# 0  2014-05-12T21:26:22.322Z  2014-05-17T00:00:00.000Z
# 1  2014-05-19T19:00:10.084Z  2014-05-24T00:00:00.000Z
# 2  2014-05-31T00:00:30.253Z  2014-06-12T00:00:00.000Z
# 3  2014-06-02T19:00:46.818Z  2014-06-07T00:00:00.000Z
# 4  2014-07-15T05:43:31.920Z  2014-07-19T00:00:00.000Z
#
#                completeDate             activatedDate  originBoardId  board_id
# 0  2014-05-19T19:11:51.658Z  2014-05-12T21:26:22.322Z             37        37
# 1  2014-06-02T19:39:27.844Z  2014-05-19T19:00:10.084Z             37        37
# 2  2014-06-13T23:05:05.267Z  2014-05-31T00:00:30.253Z             35        37
# 3  2014-07-14T16:51:27.048Z  2014-06-02T19:00:46.818Z             37        37
# 4  2014-07-25T16:28:42.789Z  2014-07-15T05:43:31.920Z             37        37

# %%
# Save as csv file
sprint_result.to_csv('Aurora_sprint.csv')

# %% [markdown]
# #### Issues

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}

payload_issues = {
'maxResults':3000
}

list1 = []
# Loop through the required board, and store the records into the empty list1
for i in board_id:
   issues_url = 'https://issues.apache.org/jira/rest/agile/1.0/board/' + f'{i}' + '/issue'
   issues = requests.request("GET",issues_url ,headers=headers, params=payload_issues).json()
   try:
      list1.append(issues['issues'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
issue_df = pd.json_normalize(list1)
issue_df.head()
# Out:
#                                                  0    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  1    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  2    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  3    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  4    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  5    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  6    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  7    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  8    \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  9    ...  \
# 0  {'expand': 'operations,versionedRepresentation...  ...
#
#                                                  990  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  991  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  992  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  993  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  994  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  995  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  996  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  997  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  998  \
# 0  {'expand': 'operations,versionedRepresentation...
#
#                                                  999
# 0  {'expand': 'operations,versionedRepresentation...
#
# [1 rows x 1000 columns]

# %%
#Check a single record content
issue_df.iloc[0][0]
# Out:
# {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#  'id': '12992393',
#  'self': 'https://issues.apache.org/jira/rest/agile/1.0/issue/12992393',
#  'key': 'AURORA-1740',
#  'fields.fixVersions': [{'self': 'https://issues.apache.org/jira/rest/api/2/version/12335572',
#    'id': '12335572',
#    'name': '0.16.0',
#    'archived': False,
#    'released': True,
#    'releaseDate': '2016-09-28'}],
#  'fields.resolution.self': 'https://issues.apache.org/jira/rest/api/2/resolution/1',
#  'fields.resolution.id': '1',
#  'fields.resolution.description': 'A fix for this issue is checked into the tree and tested.',
#  'fields.resolution.name': 'Fixed',
#  'fields.customfield_12312322': None,
#  'fields.customfield_12312323': None,
#  'fields.customfield_12310420': '9223372036854775807',
#  'fields.customfield_12312320': None,
#  'fields.customfield_12312321': None,
#  'fields.customfield_12312328': None,
#  'fields.customfield_12312329': None,
#  'fields.customfield_12312326': None,
#  'fields.customfield_12310300': None,
#  'fields.customfield_12312327': None,
#  'fields.customfield_12312324': None,
#  'fields.customfield_12312720': None,
#  'fields.customfield_12312325': None,
#  'fields.lastViewed': None,
#  'fields.priority.self': 'https://issues.apache.org/jira/rest/api/2/priority/4',
#  'fields.priority.iconUrl': 'https://issues.apache.org/jira/images/icons/priorities/minor.svg',
#  'fields.priority.name': 'Minor',
#  'fields.priority.id': '4',
#  'fields.labels': [],
#  'fields.customfield_12312333': None,
#  'fields.customfield_12312334': None,
#  'fields.customfield_12313422': 'false',
#  'fields.customfield_12312331': None,
#  'fields.customfield_12312332': None,
#  'fields.aggregatetimeoriginalestimate': None,
#  'fields.timeestimate': None,
#  'fields.customfield_12312330': None,
#  'fields.versions': [],
#  'fields.customfield_12311120': None,
#  'fields.customfield_12313826': None,
#  'fields.issuelinks': [],
#  'fields.customfield_12312339': None,
#  'fields.customfield_12313825': None,
#  'fields.assignee.self': 'https://issues.apache.org/jira/rest/api/2/user?username=joshua.cohen',
#  'fields.assignee.name': 'joshua.cohen',
#  'fields.assignee.key': 'joshua.cohen',
#  'fields.assignee.avatarUrls.48x48': 'https://issues.apache.org/jira/secure/useravatar?ownerId=joshua.cohen&avatarId=21337',
#  'fields.assignee.avatarUrls.24x24': 'https://issues.apache.org/jira/secure/useravatar?size=small&ownerId=joshua.cohen&avatarId=21337',
#  'fields.assignee.avatarUrls.16x16': 'https://issues.apache.org/jira/secure/useravatar?size=xsmall&ownerId=joshua.cohen&avatarId=21337',
#  'fields.assignee.avatarUrls.32x32': 'https://issues.apache.org/jira/secure/useravatar?size=medium&ownerId=joshua.cohen&avatarId=21337',
#  'fields.assignee.displayName': 'Joshua Cohen',
#  'fields.assignee.active': True,
#  'fields.assignee.timeZone': 'America/Chicago',
#  'fields.customfield_12312337': None,
#  'fields.customfield_12313823': None,
#  'fields.customfield_12312338': None,
#  'fields.customfield_12311920': None,
#  'fields.customfield_12313822': None,
#  'fields.customfield_12312335': None,
#  'fields.customfield_12313821': None,
#  'fields.customfield_12312336': None,
#  'fields.customfield_12313820': None,
#  'fields.status.self': 'https://issues.apache.org/jira/rest/api/2/status/5',
#  'fields.status.description': 'A resolution has been taken, and it is awaiting verification by reporter. From here issues are either reopened, or are closed.',
#  'fields.status.iconUrl': 'https://issues.apache.org/jira/images/icons/statuses/resolved.png',
#  'fields.status.name': 'Resolved',
#  'fields.status.id': '5',
#  'fields.status.statusCategory.self': 'https://issues.apache.org/jira/rest/api/2/statuscategory/3',
#  'fields.status.statusCategory.id': 3,
#  'fields.status.statusCategory.key': 'done',
#  'fields.status.statusCategory.colorName': 'green',
#  'fields.status.statusCategory.name': 'Done',
#  'fields.components': [],
#  'fields.customfield_12312026': None,
#  'fields.customfield_12312023': None,
#  'fields.customfield_12312024': None,
#  'fields.aggregatetimeestimate': None,
#  'fields.customfield_12312022': None,
#  'fields.customfield_12310921': None,
#  'fields.customfield_12310920': '9223372036854775807',
#  'fields.customfield_12312823': None,
#  'fields.creator.self': 'https://issues.apache.org/jira/rest/api/2/user?username=joshua.cohen',
#  'fields.creator.name': 'joshua.cohen',
#  'fields.creator.key': 'joshua.cohen',
#  'fields.creator.avatarUrls.48x48': 'https://issues.apache.org/jira/secure/useravatar?ownerId=joshua.cohen&avatarId=21337',
#  'fields.creator.avatarUrls.24x24': 'https://issues.apache.org/jira/secure/useravatar?size=small&ownerId=joshua.cohen&avatarId=21337',
#  'fields.creator.avatarUrls.16x16': 'https://issues.apache.org/jira/secure/useravatar?size=xsmall&ownerId=joshua.cohen&avatarId=21337',
#  'fields.creator.avatarUrls.32x32': 'https://issues.apache.org/jira/secure/useravatar?size=medium&ownerId=joshua.cohen&avatarId=21337',
#  'fields.creator.displayName': 'Joshua Cohen',
#  'fields.creator.active': True,
#  'fields.creator.timeZone': 'America/Chicago',
#  'fields.subtasks': [],
#  'fields.reporter.self': 'https://issues.apache.org/jira/rest/api/2/user?username=joshua.cohen',
#  'fields.reporter.name': 'joshua.cohen',
#  'fields.reporter.key': 'joshua.cohen',
#  'fields.reporter.avatarUrls.48x48': 'https://issues.apache.org/jira/secure/useravatar?ownerId=joshua.cohen&avatarId=21337',
#  'fields.reporter.avatarUrls.24x24': 'https://issues.apache.org/jira/secure/useravatar?size=small&ownerId=joshua.cohen&avatarId=21337',
#  'fields.reporter.avatarUrls.16x16': 'https://issues.apache.org/jira/secure/useravatar?size=xsmall&ownerId=joshua.cohen&avatarId=21337',
#  'fields.reporter.avatarUrls.32x32': 'https://issues.apache.org/jira/secure/useravatar?size=medium&ownerId=joshua.cohen&avatarId=21337',
#  'fields.reporter.displayName': 'Joshua Cohen',
#  'fields.reporter.active': True,
#  'fields.reporter.timeZone': 'America/Chicago',
#  'fields.aggregateprogress.progress': 0,
#  'fields.aggregateprogress.total': 0,
#  'fields.customfield_12313520': None,
#  'fields.customfield_12310250': None,
#  'fields.progress.progress': 0,
#  'fields.progress.total': 0,
#  'fields.customfield_12313924': None,
#  'fields.votes.self': 'https://issues.apache.org/jira/rest/api/2/issue/AURORA-1740/votes',
#  'fields.votes.votes': 0,
#  'fields.votes.hasVoted': False,
#  'fields.worklog.startAt': 0,
#  'fields.worklog.maxResults': 20,
#  'fields.worklog.total': 0,
#  'fields.worklog.worklogs': [],
#  'fields.customfield_12313920': None,
#  'fields.issuetype.self': 'https://issues.apache.org/jira/rest/api/2/issuetype/3',
#  'fields.issuetype.id': '3',
#  'fields.issuetype.description': 'A task that needs to be done.',
#  'fields.issuetype.iconUrl': 'https://issues.apache.org/jira/secure/viewavatar?size=xsmall&avatarId=21148&avatarType=issuetype',
#  'fields.issuetype.name': 'Task',
#  'fields.issuetype.subtask': False,
#  'fields.issuetype.avatarId': 21148,
#  'fields.timespent': None,
#  'fields.customfield_12314020': '{summaryBean=com.atlassian.jira.plugin.devstatus.rest.SummaryBean@269e0fab[summary={pullrequest=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@4685f96d[overall=PullRequestOverallBean{stateCount=0, state=\'OPEN\', details=PullRequestOverallDetails{openCount=0, mergedCount=0, declinedCount=0}},byInstanceType={}], build=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@39e3886a[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BuildOverallBean@50c450aa[failedBuildCount=0,successfulBuildCount=0,unknownBuildCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], review=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@343c9adb[overall=com.atlassian.jira.plugin.devstatus.summary.beans.ReviewsOverallBean@6abf0071[stateCount=0,state=<null>,dueDate=<null>,overDue=false,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], deployment-environment=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@4f3a7594[overall=com.atlassian.jira.plugin.devstatus.summary.beans.DeploymentOverallBean@3d093dd9[topEnvironments=[],showProjects=false,successfulCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], repository=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@6d3392e1[overall=com.atlassian.jira.plugin.devstatus.summary.beans.CommitOverallBean@7f1dbbbe[count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], branch=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@6317f71c[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BranchOverallBean@1784f952[count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}]},errors=[],configErrors=[]], devSummaryJson={"cachedValue":{"errors":[],"configErrors":[],"summary":{"pullrequest":{"overall":{"count":0,"lastUpdated":null,"stateCount":0,"state":"OPEN","details":{"openCount":0,"mergedCount":0,"declinedCount":0,"total":0},"open":true},"byInstanceType":{}},"build":{"overall":{"count":0,"lastUpdated":null,"failedBuildCount":0,"successfulBuildCount":0,"unknownBuildCount":0},"byInstanceType":{}},"review":{"overall":{"count":0,"lastUpdated":null,"stateCount":0,"state":null,"dueDate":null,"overDue":false,"completed":false},"byInstanceType":{}},"deployment-environment":{"overall":{"count":0,"lastUpdated":null,"topEnvironments":[],"showProjects":false,"successfulCount":0},"byInstanceType":{}},"repository":{"overall":{"count":0,"lastUpdated":null},"byInstanceType":{}},"branch":{"overall":{"count":0,"lastUpdated":null},"byInstanceType":{}}}},"isStale":false}}',
#  'fields.customfield_12314141': None,
#  'fields.customfield_12314140': None,
#  'fields.project.self': 'https://issues.apache.org/jira/rest/api/2/project/12314922',
#  'fields.project.id': '12314922',
#  'fields.project.key': 'AURORA',
#  'fields.project.name': 'Aurora',
#  'fields.project.projectTypeKey': 'software',
#  'fields.project.avatarUrls.48x48': 'https://issues.apache.org/jira/secure/projectavatar?pid=12314922&avatarId=19299',
#  'fields.project.avatarUrls.24x24': 'https://issues.apache.org/jira/secure/projectavatar?size=small&pid=12314922&avatarId=19299',
#  'fields.project.avatarUrls.16x16': 'https://issues.apache.org/jira/secure/projectavatar?size=xsmall&pid=12314922&avatarId=19299',
#  'fields.project.avatarUrls.32x32': 'https://issues.apache.org/jira/secure/projectavatar?size=medium&pid=12314922&avatarId=19299',
#  'fields.project.projectCategory.self': 'https://issues.apache.org/jira/rest/api/2/projectCategory/13160',
#  'fields.project.projectCategory.id': '13160',
#  'fields.project.projectCategory.description': 'Apache Aurora',
#  'fields.project.projectCategory.name': 'Aurora',
#  'fields.aggregatetimespent': None,
#  'fields.customfield_12312520': None,
#  'fields.customfield_12314422': None,
#  'fields.customfield_12314421': None,
#  'fields.customfield_12314146': None,
#  'fields.customfield_12314420': None,
#  'fields.customfield_12314145': None,
#  'fields.customfield_12314144': None,
#  'fields.customfield_12314143': None,
#  'fields.resolutiondate': '2016-08-05T17:14:24.000+0000',
#  'fields.workratio': -1,
#  'fields.customfield_12312923': None,
#  'fields.customfield_12312920': None,
#  'fields.customfield_12312921': None,
#  'fields.watches.self': 'https://issues.apache.org/jira/rest/api/2/issue/AURORA-1740/watchers',
#  'fields.watches.watchCount': 2,
#  'fields.watches.isWatching': False,
#  'fields.created': '2016-07-25T20:39:31.000+0000',
#  'fields.updated': '2016-09-19T18:49:34.000+0000',
#  'fields.timeoriginalestimate': None,
#  'fields.description': None,
#  'fields.customfield_10010': None,
#  'fields.customfield_12314523': None,
#  'fields.customfield_12314127': None,
#  'fields.customfield_12314522': None,
#  'fields.customfield_12314126': None,
#  'fields.customfield_12314521': None,
#  'fields.customfield_12314125': None,
#  'fields.customfield_12314520': None,
#  'fields.customfield_12314124': None,
#  'fields.customfield_12312340': None,
#  'fields.attachment': [],
#  'fields.customfield_12314123': None,
#  'fields.flagged': False,
#  'fields.customfield_12312341': None,
#  'fields.customfield_12312220': None,
#  'fields.customfield_12314122': None,
#  'fields.customfield_12314121': None,
#  'fields.customfield_12314120': None,
#  'fields.customfield_12314129': None,
#  'fields.customfield_12314524': None,
#  'fields.customfield_12314128': None,
#  'fields.summary': 'Upgrade to Mesos 1.0.0',
#  'fields.customfield_12314130': None,
#  'fields.customfield_12310291': None,
#  'fields.customfield_12310290': None,
#  'fields.customfield_12311024': None,
#  'fields.customfield_12314138': None,
#  'fields.customfield_12314137': None,
#  'fields.environment': None,
#  'fields.customfield_12314136': None,
#  'fields.customfield_12314135': None,
#  'fields.customfield_12311020': None,
#  'fields.customfield_12310293': None,
#  'fields.customfield_12314134': None,
#  'fields.duedate': None,
#  'fields.customfield_12314132': None,
#  'fields.customfield_12314131': None,
#  'fields.comment.comments': [],
#  'fields.comment.maxResults': 0,
#  'fields.comment.total': 0,
#  'fields.comment.startAt': 0,
#  'fields.customfield_12311820': '0|hzzzbp:',
#  'fields.customfield_12314139': None}

# %%
issue_result = pd.DataFrame()

for i in issue_df.index:
   issue_df_1 = issue_df.iloc[i].apply(pd.Series)
   issue_df_1['board_id'] = board_df['id'][i]
   frame = [issue_result, issue_df_1]
   issue_result = pd.concat(frame)

issue_result = issue_result.reset_index()
issue_result = issue_result.drop(columns=['index'])

# %%
#Only select issues that have story points
issue_result = issue_result[issue_result['fields.customfield_12310293'].notna()]
issue_result.head()
# Out:
#                                                expand        id  \
# 5   operations,versionedRepresentations,editmeta,c...  12819021
# 9   operations,versionedRepresentations,editmeta,c...  12901444
# 11  operations,versionedRepresentations,editmeta,c...  12818763
# 12  operations,versionedRepresentations,editmeta,c...  12901982
# 13  operations,versionedRepresentations,editmeta,c...  12839636
#
#                                                  self          key  \
# 5   https://issues.apache.org/jira/rest/agile/1.0/...  AURORA-1258
# 9   https://issues.apache.org/jira/rest/agile/1.0/...  AURORA-1506
# 11  https://issues.apache.org/jira/rest/agile/1.0/...  AURORA-1250
# 12  https://issues.apache.org/jira/rest/agile/1.0/...  AURORA-1511
# 13  https://issues.apache.org/jira/rest/agile/1.0/...  AURORA-1364
#
#                                    fields.fixVersions  \
# 5   [{'self': 'https://issues.apache.org/jira/rest...
# 9   [{'self': 'https://issues.apache.org/jira/rest...
# 11  [{'self': 'https://issues.apache.org/jira/rest...
# 12  [{'self': 'https://issues.apache.org/jira/rest...
# 13  [{'self': 'https://issues.apache.org/jira/rest...
#
#                                fields.resolution.self fields.resolution.id  \
# 5   https://issues.apache.org/jira/rest/api/2/reso...                    1
# 9   https://issues.apache.org/jira/rest/api/2/reso...                    1
# 11  https://issues.apache.org/jira/rest/api/2/reso...                    1
# 12  https://issues.apache.org/jira/rest/api/2/reso...                    1
# 13  https://issues.apache.org/jira/rest/api/2/reso...                    1
#
#                         fields.resolution.description fields.resolution.name  \
# 5   A fix for this issue is checked into the tree ...                  Fixed
# 9   A fix for this issue is checked into the tree ...                  Fixed
# 11  A fix for this issue is checked into the tree ...                  Fixed
# 12  A fix for this issue is checked into the tree ...                  Fixed
# 13  A fix for this issue is checked into the tree ...                  Fixed
#
#    fields.customfield_12312322  ... fields.sprint.originBoardId  \
# 5                         None  ...                         NaN
# 9                         None  ...                         NaN
# 11                        None  ...                         NaN
# 12                        None  ...                         NaN
# 13                        None  ...                         NaN
#
#    fields.resolution fields.assignee fields.aggregateprogress.percent  \
# 5                NaN             NaN                              NaN
# 9                NaN             NaN                              NaN
# 11               NaN             NaN                              NaN
# 12               NaN             NaN                              NaN
# 13               NaN             NaN                              NaN
#
#    fields.progress.percent fields.timetracking.originalEstimate  \
# 5                      NaN                                  NaN
# 9                      NaN                                  NaN
# 11                     NaN                                  NaN
# 12                     NaN                                  NaN
# 13                     NaN                                  NaN
#
#    fields.timetracking.remainingEstimate  \
# 5                                    NaN
# 9                                    NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
#
#    fields.timetracking.originalEstimateSeconds  \
# 5                                          NaN
# 9                                          NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
#
#    fields.timetracking.remainingEstimateSeconds board_id
# 5                                           NaN       37
# 9                                           NaN       37
# 11                                          NaN       37
# 12                                          NaN       37
# 13                                          NaN       37
#
# [5 rows x 229 columns]

# %%
#Check the dataframe shape
issue_result.shape
# Out:
# (2610, 336)

# %%
#Save as csv file
issue_result.to_csv('YourProjectName_issues.csv')
