# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import base64
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#For RedHat, just replace your token and keep string "Bearer"
#auth = "Bearer MDE2NzE5MzE3NDc4OnE7nyt5UfoYVwX+dHghlBoYiOAH"

#For Apache, you can use same method as RedHat, if it doesn't work, please try the following

# Also for Apache, please use following format to retrieve data.
url = 'https://issues.redhat.com/rest/agile/1.0/board?projectKeyOrId=KOGITO'
headers = {
   "Accept": "application/json",
   "Authorization": "Bearer MDE2NzE5MzE3NDc4OnE7nyt5UfoYVwX+dHghlBoYiOAH",
}

payload = {
   "maxResults":50 
}

board_url = requests.request("GET",url,headers=headers, params=payload).json()

# %%
# Replace BaseURL and project key with your own project
board_url = 'https://issues.redhat.com/rest/agile/1.0/board?projectKeyOrId=KOGITO'

headers = {
   "Accept": "application/json",
   "Authorization": "Bearer MDE2NzE5MzE3NDc4OnE7nyt5UfoYVwX+dHghlBoYiOAH",
}

payload = {
   "maxResults":50 #100, 20
}

# Request data by using GET method and directly get the json output
board = requests.request("GET",board_url,headers=headers, params=payload).json()

# As we only intreseted in the "values" in the board, so we only normalize the board['values']
board_df = pd.json_normalize(board['values'])

# Filter the scrum board type and maintain the pd dataframe formate
board_df = board_df[board_df['type']=='scrum']

# Reset the index for the future convience.
board_df = board_df.reset_index()

# Store the board id into variable board_id
board_id = board_df['id']

#Save the df as csv file. Use your project name to define the file name
board_df.to_csv('KOGITO_board.csv')

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": "Bearer MDE2NzE5MzE3NDc4OnE7nyt5UfoYVwX+dHghlBoYiOAH",  
}


payload_sprint = {
'maxResults':2000  #Retrieve at most 2000 records, can be modified based on your own project
}

list1 = [] 

# Loop through the required board, and store the records into the empty list1
for i in board_id:
   sprint_url = 'https://issues.redhat.com/rest/agile/1.0/board/' + f'{i}' + '/sprint'
   sprint = requests.request("GET",sprint_url ,headers=headers, params=payload_sprint).json()
   try:
      list1.append(sprint['values'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
sprint_df = pd.json_normalize(list1)
sprint_df.head()
# Out:
#                                                   0   \
# 0  {'id': 5712, 'self': 'https://issues.redhat.co...
# 1  {'id': 8166, 'self': 'https://issues.redhat.co...
# 2  {'id': 3222, 'self': 'https://issues.redhat.co...
# 3  {'id': 8166, 'self': 'https://issues.redhat.co...
# 4  {'id': 4660, 'self': 'https://issues.redhat.co...
#
#                                                   1   \
# 0  {'id': 6002, 'self': 'https://issues.redhat.co...
# 1  {'id': 8514, 'self': 'https://issues.redhat.co...
# 2  {'id': 3352, 'self': 'https://issues.redhat.co...
# 3  {'id': 8514, 'self': 'https://issues.redhat.co...
# 4  {'id': 5140, 'self': 'https://issues.redhat.co...
#
#                                                   2   \
# 0  {'id': 6016, 'self': 'https://issues.redhat.co...
# 1  {'id': 8516, 'self': 'https://issues.redhat.co...
# 2  {'id': 3362, 'self': 'https://issues.redhat.co...
# 3  {'id': 8516, 'self': 'https://issues.redhat.co...
# 4  {'id': 5214, 'self': 'https://issues.redhat.co...
#
#                                                   3   \
# 0  {'id': 6066, 'self': 'https://issues.redhat.co...
# 1  {'id': 8518, 'self': 'https://issues.redhat.co...
# 2  {'id': 3372, 'self': 'https://issues.redhat.co...
# 3  {'id': 8518, 'self': 'https://issues.redhat.co...
# 4  {'id': 5408, 'self': 'https://issues.redhat.co...
#
#                                                   4   \
# 0  {'id': 6076, 'self': 'https://issues.redhat.co...
# 1  {'id': 8520, 'self': 'https://issues.redhat.co...
# 2  {'id': 3382, 'self': 'https://issues.redhat.co...
# 3  {'id': 8520, 'self': 'https://issues.redhat.co...
# 4  {'id': 5504, 'self': 'https://issues.redhat.co...
#
#                                                   5   \
# 0  {'id': 6126, 'self': 'https://issues.redhat.co...
# 1  {'id': 8932, 'self': 'https://issues.redhat.co...
# 2  {'id': 3392, 'self': 'https://issues.redhat.co...
# 3  {'id': 8932, 'self': 'https://issues.redhat.co...
# 4  {'id': 5622, 'self': 'https://issues.redhat.co...
#
#                                                   6   \
# 0  {'id': 6130, 'self': 'https://issues.redhat.co...
# 1  {'id': 8934, 'self': 'https://issues.redhat.co...
# 2  {'id': 4848, 'self': 'https://issues.redhat.co...
# 3  {'id': 8934, 'self': 'https://issues.redhat.co...
# 4  {'id': 5644, 'self': 'https://issues.redhat.co...
#
#                                                   7   \
# 0  {'id': 6146, 'self': 'https://issues.redhat.co...
# 1  {'id': 8936, 'self': 'https://issues.redhat.co...
# 2  {'id': 4660, 'self': 'https://issues.redhat.co...
# 3  {'id': 8936, 'self': 'https://issues.redhat.co...
# 4  {'id': 5646, 'self': 'https://issues.redhat.co...
#
#                                                   8   \
# 0  {'id': 6156, 'self': 'https://issues.redhat.co...
# 1  {'id': 8938, 'self': 'https://issues.redhat.co...
# 2  {'id': 4412, 'self': 'https://issues.redhat.co...
# 3  {'id': 8938, 'self': 'https://issues.redhat.co...
# 4  {'id': 5712, 'self': 'https://issues.redhat.co...
#
#                                                   9   ...  \
# 0  {'id': 6180, 'self': 'https://issues.redhat.co...  ...
# 1  {'id': 9122, 'self': 'https://issues.redhat.co...  ...
# 2  {'id': 4896, 'self': 'https://issues.redhat.co...  ...
# 3  {'id': 9122, 'self': 'https://issues.redhat.co...  ...
# 4  {'id': 5932, 'self': 'https://issues.redhat.co...  ...
#
#                                                   40  \
# 0  {'id': 7914, 'self': 'https://issues.redhat.co...
# 1  {'id': 25171, 'self': 'https://issues.redhat.c...
# 2  {'id': 6287, 'self': 'https://issues.redhat.co...
# 3  {'id': 25171, 'self': 'https://issues.redhat.c...
# 4  {'id': 6895, 'self': 'https://issues.redhat.co...
#
#                                                   41  \
# 0  {'id': 7916, 'self': 'https://issues.redhat.co...
# 1  {'id': 25172, 'self': 'https://issues.redhat.c...
# 2  {'id': 6363, 'self': 'https://issues.redhat.co...
# 3  {'id': 25172, 'self': 'https://issues.redhat.c...
# 4  {'id': 7241, 'self': 'https://issues.redhat.co...
#
#                                                   42  \
# 0  {'id': 7918, 'self': 'https://issues.redhat.co...
# 1  {'id': 25173, 'self': 'https://issues.redhat.c...
# 2  {'id': 6365, 'self': 'https://issues.redhat.co...
# 3  {'id': 25173, 'self': 'https://issues.redhat.c...
# 4  {'id': 6915, 'self': 'https://issues.redhat.co...
#
#                                                   43  \
# 0  {'id': 8160, 'self': 'https://issues.redhat.co...
# 1  {'id': 25174, 'self': 'https://issues.redhat.c...
# 2  {'id': 6377, 'self': 'https://issues.redhat.co...
# 3  {'id': 25174, 'self': 'https://issues.redhat.c...
# 4  {'id': 6979, 'self': 'https://issues.redhat.co...
#
#                                                   44  \
# 0  {'id': 8158, 'self': 'https://issues.redhat.co...
# 1  {'id': 25175, 'self': 'https://issues.redhat.c...
# 2  {'id': 6387, 'self': 'https://issues.redhat.co...
# 3  {'id': 25175, 'self': 'https://issues.redhat.c...
# 4  {'id': 7289, 'self': 'https://issues.redhat.co...
#
#                                                   45  \
# 0  {'id': 8162, 'self': 'https://issues.redhat.co...
# 1  {'id': 38867, 'self': 'https://issues.redhat.c...
# 2  {'id': 6627, 'self': 'https://issues.redhat.co...
# 3  {'id': 38867, 'self': 'https://issues.redhat.c...
# 4  {'id': 7061, 'self': 'https://issues.redhat.co...
#
#                                                   46  \
# 0  {'id': 8164, 'self': 'https://issues.redhat.co...
# 1  {'id': 38868, 'self': 'https://issues.redhat.c...
# 2  {'id': 6633, 'self': 'https://issues.redhat.co...
# 3  {'id': 38868, 'self': 'https://issues.redhat.c...
# 4  {'id': 7173, 'self': 'https://issues.redhat.co...
#
#                                                   47  \
# 0  {'id': 8166, 'self': 'https://issues.redhat.co...
# 1  {'id': 38869, 'self': 'https://issues.redhat.c...
# 2  {'id': 6531, 'self': 'https://issues.redhat.co...
# 3  {'id': 38869, 'self': 'https://issues.redhat.c...
# 4  {'id': 7187, 'self': 'https://issues.redhat.co...
#
#                                                   48  \
# 0  {'id': 8514, 'self': 'https://issues.redhat.co...
# 1  {'id': 40100, 'self': 'https://issues.redhat.c...
# 2  {'id': 6851, 'self': 'https://issues.redhat.co...
# 3  {'id': 40100, 'self': 'https://issues.redhat.c...
# 4  {'id': 7189, 'self': 'https://issues.redhat.co...
#
#                                                   49
# 0  {'id': 8516, 'self': 'https://issues.redhat.co...
# 1  {'id': 40625, 'self': 'https://issues.redhat.c...
# 2  {'id': 6725, 'self': 'https://issues.redhat.co...
# 3  {'id': 40625, 'self': 'https://issues.redhat.c...
# 4  {'id': 7191, 'self': 'https://issues.redhat.co...
#
# [5 rows x 50 columns]

# %%
#Create an empty dataframe
sprint_result = pd.DataFrame()
sprint_result.head()

# sprint_df.index is the row number. For each row, we need to flatten the records and store them into a dataframe. Our goal is to flatten all these record and generate a single dataframe.
for i in sprint_df.index:
   # Flatten records in a row based on row index
   sprint_df_1 = sprint_df.iloc[i].apply(pd.Series) 
   # Attach corresponding board_id
   sprint_df_1['board_id'] = board_df['id'][i]
   # Create a list called "frame" to tell python we want to contact two dataframs together -- sprint_result and sprint_df_1
   frame = [sprint_result, sprint_df_1]
   #Contact two dataframes
   sprint_result = pd.concat(frame)

# %%
# Filter the sprint that totally empty
sprint_result = sprint_result[sprint_result['id'].notna()]
sprint_result.head()
# Out:
#        id                                               self   state  \
# 0  5712.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 1  6002.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 2  6016.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 3  6066.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 4  6076.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
#
#             name                 startDate                   endDate  \
# 0        Sprint3  2017-03-14T15:15:25.335Z  2017-05-13T03:59:00.000Z
# 1  jBPM sprint 1  2017-04-16T12:01:50.706Z  2017-04-30T12:01:00.000Z
# 2  jBPM sprint 2  2017-05-01T08:21:21.902Z  2017-05-15T08:21:00.000Z
# 3  jBPM sprint 3  2017-05-15T05:32:07.785Z  2017-05-29T05:32:00.000Z
# 4       Sprint 3  2017-05-24T13:23:20.039Z  2017-06-07T13:23:00.000Z
#
#                completeDate             activatedDate  originBoardId goal  \
# 0  2017-05-15T14:02:18.358Z  2017-03-14T15:15:25.335Z         3838.0  NaN
# 1  2017-05-08T08:20:21.509Z  2017-04-16T12:01:50.706Z         3972.0  NaN
# 2  2017-05-15T05:32:14.614Z  2017-05-01T08:21:21.902Z         3972.0  NaN
# 3  2017-05-29T15:21:10.611Z  2017-05-15T05:32:07.785Z         3972.0  NaN
# 4  2017-06-06T11:53:28.159Z  2017-05-24T13:23:20.039Z         3942.0  NaN
#
#    board_id
# 0      6473
# 1      6473
# 2      6473
# 3      6473
# 4      6473

# %%
# Reset the index
sprint_result = sprint_result.reset_index()
# Drop the origianl index column
sprint_result = sprint_result.drop(columns=['index'])
sprint_result.head()
# Out:
#        id                                               self   state  \
# 0  5712.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 1  6002.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 2  6016.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 3  6066.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 4  6076.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
#
#             name                 startDate                   endDate  \
# 0        Sprint3  2017-03-14T15:15:25.335Z  2017-05-13T03:59:00.000Z
# 1  jBPM sprint 1  2017-04-16T12:01:50.706Z  2017-04-30T12:01:00.000Z
# 2  jBPM sprint 2  2017-05-01T08:21:21.902Z  2017-05-15T08:21:00.000Z
# 3  jBPM sprint 3  2017-05-15T05:32:07.785Z  2017-05-29T05:32:00.000Z
# 4       Sprint 3  2017-05-24T13:23:20.039Z  2017-06-07T13:23:00.000Z
#
#                completeDate             activatedDate  originBoardId goal  \
# 0  2017-05-15T14:02:18.358Z  2017-03-14T15:15:25.335Z         3838.0  NaN
# 1  2017-05-08T08:20:21.509Z  2017-04-16T12:01:50.706Z         3972.0  NaN
# 2  2017-05-15T05:32:14.614Z  2017-05-01T08:21:21.902Z         3972.0  NaN
# 3  2017-05-29T15:21:10.611Z  2017-05-15T05:32:07.785Z         3972.0  NaN
# 4  2017-06-06T11:53:28.159Z  2017-05-24T13:23:20.039Z         3942.0  NaN
#
#    board_id
# 0      6473
# 1      6473
# 2      6473
# 3      6473
# 4      6473

# %%
# Save as csv file
sprint_result.to_csv('KOGITO_sprint.csv')

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": "Bearer MDE2NzE5MzE3NDc4OnE7nyt5UfoYVwX+dHghlBoYiOAH",  
}

payload_issues = {
'maxResults':3000
}

list1 = []
# Loop through the required board, and store the records into the empty list1
for i in board_id:
   issues_url = 'https://issues.redhat.com/rest/agile/1.0/board/' + f'{i}' + '/issue'
   issues = requests.request("GET",issues_url ,headers=headers, params=payload_issues).json()
   try:
      list1.append(issues['issues'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
issue_df = pd.json_normalize(list1)
issue_df.head()
# Out:
#                                                  0    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  1    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  2    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  3    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  4    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  5    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  6    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  7    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  8    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  9    ...  \
# 0  {'expand': 'operations,versionedRepresentation...  ...
# 1  {'expand': 'operations,versionedRepresentation...  ...
# 2  {'expand': 'operations,versionedRepresentation...  ...
# 3  {'expand': 'operations,versionedRepresentation...  ...
# 4  {'expand': 'operations,versionedRepresentation...  ...
#
#                                                  990  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  991  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  992  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  993  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  994  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  995  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  996  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  997  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  998  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  999
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
# [5 rows x 1000 columns]

# %%
#Check a single record content
issue_df.iloc[0][0]
# Out:
# {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#  'fields.aggregateprogress.progress': 0,
#  'fields.aggregateprogress.total': 0,
#  'fields.aggregatetimeestimate': None,
#  'fields.aggregatetimeoriginalestimate': None,
#  'fields.aggregatetimespent': None,
#  'fields.archivedby': None,
#  'fields.archiveddate': None,
#  'fields.assignee.active': True,
#  'fields.assignee.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#  'fields.assignee.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#  'fields.assignee.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409',
#  'fields.assignee.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#  'fields.assignee.displayName': 'Edoardo Vacchi',
#  'fields.assignee.emailAddress': 'evacchi@redhat.com',
#  'fields.assignee.key': 'evacchi',
#  'fields.assignee.name': 'evacchi',
#  'fields.assignee.self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#  'fields.assignee.timeZone': 'Europe/Rome',
#  'fields.attachment': [],
#  'fields.closedSprints': [{'activatedDate': '2022-02-02T11:20:12.478Z',
#    'completeDate': '2022-02-21T15:37:12.832Z',
#    'endDate': '2022-02-20T23:59:00.000Z',
#    'goal': '',
#    'id': 40625,
#    'name': '2022 Week 05-07 (from Jan 31)',
#    'originBoardId': 4036,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/40625',
#    'startDate': '2022-02-02T00:01:00.000Z',
#    'state': 'closed'}],
#  'fields.comment.comments': [],
#  'fields.comment.maxResults': 0,
#  'fields.comment.startAt': 0,
#  'fields.comment.total': 0,
#  'fields.components': [{'id': '12332741',
#    'name': 'Core',
#    'self': 'https://issues.redhat.com/rest/api/2/component/12332741'}],
#  'fields.created': '2022-01-28T16:48:07.000+0000',
#  'fields.creator.active': True,
#  'fields.creator.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#  'fields.creator.displayName': 'Edoardo Vacchi',
#  'fields.creator.emailAddress': 'evacchi@redhat.com',
#  'fields.creator.key': 'evacchi',
#  'fields.creator.name': 'evacchi',
#  'fields.creator.self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#  'fields.creator.timeZone': 'Europe/Rome',
#  'fields.customfield_12310010': None,
#  'fields.customfield_12310031': None,
#  'fields.customfield_12310070': None,
#  'fields.customfield_12310080.active': True,
#  'fields.customfield_12310080.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=mmacik&avatarId=25578',
#  'fields.customfield_12310080.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=mmacik&avatarId=25578',
#  'fields.customfield_12310080.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=mmacik&avatarId=25578',
#  'fields.customfield_12310080.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=mmacik&avatarId=25578',
#  'fields.customfield_12310080.displayName': 'Marian Macik',
#  'fields.customfield_12310080.emailAddress': 'mmacik@redhat.com',
#  'fields.customfield_12310080.key': 'mmacik',
#  'fields.customfield_12310080.name': 'mmacik@redhat.com',
#  'fields.customfield_12310080.self': 'https://issues.redhat.com/rest/api/2/user?username=mmacik%40redhat.com',
#  'fields.customfield_12310080.timeZone': 'Europe/Berlin',
#  'fields.customfield_12310092': None,
#  'fields.customfield_12310120': None,
#  'fields.customfield_12310211': None,
#  'fields.customfield_12310213': None,
#  'fields.customfield_12310220': None,
#  'fields.customfield_12310243': None,
#  'fields.customfield_12310840': '9223372036854775807',
#  'fields.customfield_12310940': ['com.atlassian.greenhopper.service.sprint.Sprint@706812d[id=40625,rapidViewId=4036,state=CLOSED,name=2022 Week 05-07 (from Jan 31),startDate=2022-02-02T00:01:00.000Z,endDate=2022-02-20T23:59:00.000Z,completeDate=2022-02-21T15:37:12.832Z,activatedDate=2022-02-02T11:20:12.478Z,sequence=40625,goal=,autoStartStop=false]'],
#  'fields.customfield_12311140': None,
#  'fields.customfield_12311240': None,
#  'fields.customfield_12311241': None,
#  'fields.customfield_12311242': None,
#  'fields.customfield_12311243': None,
#  'fields.customfield_12311244': None,
#  'fields.customfield_12311245': None,
#  'fields.customfield_12311640': None,
#  'fields.customfield_12311641': None,
#  'fields.customfield_12311840': None,
#  'fields.customfield_12311940': '1|hxyht1:c',
#  'fields.customfield_12311941': None,
#  'fields.customfield_12313140': None,
#  'fields.customfield_12313240': None,
#  'fields.customfield_12313440': '',
#  'fields.customfield_12313441': '',
#  'fields.customfield_12313941': None,
#  'fields.customfield_12313942': None,
#  'fields.customfield_12314040': None,
#  'fields.customfield_12314740': '{summaryBean=com.atlassian.jira.plugin.devstatus.rest.SummaryBean@722c6e59[summary={pullrequest=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@3cf0be1d[overall=PullRequestOverallBean{stateCount=1, state=\'MERGED\', details=PullRequestOverallDetails{openCount=0, mergedCount=1, declinedCount=0}},byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@4770370d[count=1,name=GitHub]}], build=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@7e4979a8[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BuildOverallBean@f81e1ff[failedBuildCount=0,successfulBuildCount=0,unknownBuildCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], review=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@27bf9bc7[overall=com.atlassian.jira.plugin.devstatus.summary.beans.ReviewsOverallBean@61311862[stateCount=0,state=<null>,dueDate=<null>,overDue=false,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], deployment-environment=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@5400b9d5[overall=com.atlassian.jira.plugin.devstatus.summary.beans.DeploymentOverallBean@548e24b3[topEnvironments=[],showProjects=false,successfulCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], repository=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@fb4ec46[overall=com.atlassian.jira.plugin.devstatus.summary.beans.CommitOverallBean@662f17da[count=1,lastUpdated=2022-02-16T15:17:13.000+0000,lastUpdatedTimestamp=2022-02-16T15:17:13.000Z],byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@37b0c4db[count=1,name=GitHub]}], branch=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@123ed522[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BranchOverallBean@3a40ddff[count=1,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@24cf9caa[count=1,name=GitHub]}]},errors=[],configErrors=[]], devSummaryJson={"cachedValue":{"errors":[],"configErrors":[],"summary":{"pullrequest":{"overall":{"count":1,"lastUpdated":"2022-02-16T15:17:17.000+0000","stateCount":1,"state":"MERGED","details":{"openCount":0,"mergedCount":1,"declinedCount":0,"total":1},"open":false},"byInstanceType":{"github":{"count":1,"name":"GitHub"}}},"build":{"overall":{"count":0,"lastUpdated":null,"failedBuildCount":0,"successfulBuildCount":0,"unknownBuildCount":0},"byInstanceType":{}},"review":{"overall":{"count":0,"lastUpdated":null,"stateCount":0,"state":null,"dueDate":null,"overDue":false,"completed":false},"byInstanceType":{}},"deployment-environment":{"overall":{"count":0,"lastUpdated":null,"topEnvironments":[],"showProjects":false,"successfulCount":0},"byInstanceType":{}},"repository":{"overall":{"count":1,"lastUpdated":"2022-02-16T15:17:13.000+0000"},"byInstanceType":{"github":{"count":1,"name":"GitHub"}}},"branch":{"overall":{"count":1,"lastUpdated":null},"byInstanceType":{"github":{"count":1,"name":"GitHub"}}}}},"isStale":true}}',
#  'fields.customfield_12315542': None,
#  'fields.customfield_12315740': None,
#  'fields.customfield_12315840': None,
#  'fields.customfield_12315841': None,
#  'fields.customfield_12315944': None,
#  'fields.customfield_12315950': None,
#  'fields.customfield_12316341': None,
#  'fields.customfield_12316542.disabled': False,
#  'fields.customfield_12316542.id': '14655',
#  'fields.customfield_12316542.self': 'https://issues.redhat.com/rest/api/2/customFieldOption/14655',
#  'fields.customfield_12316542.value': 'False',
#  'fields.customfield_12316543.disabled': False,
#  'fields.customfield_12316543.id': '14657',
#  'fields.customfield_12316543.self': 'https://issues.redhat.com/rest/api/2/customFieldOption/14657',
#  'fields.customfield_12316543.value': 'False',
#  'fields.customfield_12316544': None,
#  'fields.customfield_12316841': None,
#  'fields.customfield_12317275': None,
#  'fields.customfield_12317276': None,
#  'fields.customfield_12317313': None,
#  'fields.customfield_12317367': None,
#  'fields.customfield_12317368': None,
#  'fields.customfield_12317379': None,
#  'fields.customfield_12318341': None,
#  'fields.customfield_12319743': None,
#  'fields.customfield_12320640': None,
#  'fields.customfield_12320940': None,
#  'fields.customfield_12320944': None,
#  'fields.description': 'Rule codegen does not clearly separate the REST part from the non-REST part. Refactor the component so that the two parts are clearly separated to prepare for further refactoring (i.e. move the non-REST part to Drools)',
#  'fields.duedate': None,
#  'fields.fixVersions': [{'archived': False,
#    'description': '',
#    'id': '12377755',
#    'name': '1.18.0.Final',
#    'releaseDate': '2022-03-07',
#    'released': True,
#    'self': 'https://issues.redhat.com/rest/api/2/version/12377755'}],
#  'fields.flagged': False,
#  'fields.issuelinks': [{'id': '14061650',
#    'outwardIssue': {'fields': {'issuetype': {'avatarId': 13275,
#       'description': 'Created by Jira Software - do not edit or delete. Issue type for a user story.',
#       'iconUrl': 'https://issues.redhat.com/secure/viewavatar?size=xsmall&avatarId=13275&avatarType=issuetype',
#       'id': '17',
#       'name': 'Story',
#       'self': 'https://issues.redhat.com/rest/api/2/issuetype/17',
#       'subtask': False},
#      'priority': {'iconUrl': 'https://issues.redhat.com/images/icons/priorities/major.svg',
#       'id': '3',
#       'name': 'Major',
#       'self': 'https://issues.redhat.com/rest/api/2/priority/3'},
#      'status': {'description': 'This issue is being actively worked on at the moment by the assignee.',
#       'iconUrl': 'https://issues.redhat.com/images/icons/statuses/inprogress.png',
#       'id': '3',
#       'name': 'Coding In Progress',
#       'self': 'https://issues.redhat.com/rest/api/2/status/3',
#       'statusCategory': {'colorName': 'yellow',
#        'id': 4,
#        'key': 'indeterminate',
#        'name': 'In Progress',
#        'self': 'https://issues.redhat.com/rest/api/2/statuscategory/4'}},
#      'summary': 'Move rule unit related code generation from Kogito to Drools'},
#     'id': '14454194',
#     'key': 'DROOLS-6802',
#     'self': 'https://issues.redhat.com/rest/api/2/issue/14454194'},
#    'self': 'https://issues.redhat.com/rest/api/2/issueLink/14061650',
#    'type': {'id': '12310720',
#     'inward': 'is blocked by',
#     'name': 'Blocks',
#     'outward': 'blocks',
#     'self': 'https://issues.redhat.com/rest/api/2/issueLinkType/12310720'}},
#   {'id': '14061651',
#    'inwardIssue': {'fields': {'issuetype': {'avatarId': 13269,
#       'description': 'An enhancement or refactoring of existing functionality',
#       'iconUrl': 'https://issues.redhat.com/secure/viewavatar?size=xsmall&avatarId=13269&avatarType=issuetype',
#       'id': '13',
#       'name': 'Enhancement',
#       'self': 'https://issues.redhat.com/rest/api/2/issuetype/13',
#       'subtask': False},
#      'priority': {'iconUrl': 'https://issues.redhat.com/images/icons/priorities/major.svg',
#       'id': '3',
#       'name': 'Major',
#       'self': 'https://issues.redhat.com/rest/api/2/priority/3'},
#      'status': {'description': 'For teams with longer stakeholder feedback loops (multiple days before they typically respond), this status can be used to indicate the work is done and deployed, but still awaiting sign-off from the requester(s). It is different from Release Pending because the work has been deployed. This is meant for help-desk style interactions, not product development.',
#       'iconUrl': 'https://issues.redhat.com/images/icons/statuses/resolved.png',
#       'id': '5',
#       'name': 'Resolved',
#       'self': 'https://issues.redhat.com/rest/api/2/status/5',
#       'statusCategory': {'colorName': 'green',
#        'id': 3,
#        'key': 'done',
#        'name': 'Done',
#        'self': 'https://issues.redhat.com/rest/api/2/statuscategory/3'}},
#      'summary': 'Rename Rule Codegen'},
#     'id': '14457617',
#     'key': 'KOGITO-6674',
#     'self': 'https://issues.redhat.com/rest/api/2/issue/14457617'},
#    'self': 'https://issues.redhat.com/rest/api/2/issueLink/14061651',
#    'type': {'id': '12310720',
#     'inward': 'is blocked by',
#     'name': 'Blocks',
#     'outward': 'blocks',
#     'self': 'https://issues.redhat.com/rest/api/2/issueLinkType/12310720'}}],
#  'fields.issuetype.avatarId': 13269,
#  'fields.issuetype.description': 'An enhancement or refactoring of existing functionality',
#  'fields.issuetype.iconUrl': 'https://issues.redhat.com/secure/viewavatar?size=xsmall&avatarId=13269&avatarType=issuetype',
#  'fields.issuetype.id': '13',
#  'fields.issuetype.name': 'Enhancement',
#  'fields.issuetype.self': 'https://issues.redhat.com/rest/api/2/issuetype/13',
#  'fields.issuetype.subtask': False,
#  'fields.labels': ['drools-core'],
#  'fields.lastViewed': None,
#  'fields.priority.iconUrl': 'https://issues.redhat.com/images/icons/priorities/major.svg',
#  'fields.priority.id': '3',
#  'fields.priority.name': 'Major',
#  'fields.priority.self': 'https://issues.redhat.com/rest/api/2/priority/3',
#  'fields.progress.progress': 0,
#  'fields.progress.total': 0,
#  'fields.project.avatarUrls.16x16': 'https://issues.redhat.com/secure/projectavatar?size=xsmall&pid=12322421&avatarId=24060',
#  'fields.project.avatarUrls.24x24': 'https://issues.redhat.com/secure/projectavatar?size=small&pid=12322421&avatarId=24060',
#  'fields.project.avatarUrls.32x32': 'https://issues.redhat.com/secure/projectavatar?size=medium&pid=12322421&avatarId=24060',
#  'fields.project.avatarUrls.48x48': 'https://issues.redhat.com/secure/projectavatar?pid=12322421&avatarId=24060',
#  'fields.project.id': '12322421',
#  'fields.project.key': 'KOGITO',
#  'fields.project.name': 'Kogito',
#  'fields.project.projectCategory.description': 'Projects related to Services.',
#  'fields.project.projectCategory.id': '10094',
#  'fields.project.projectCategory.name': 'Services',
#  'fields.project.projectCategory.self': 'https://issues.redhat.com/rest/api/2/projectCategory/10094',
#  'fields.project.projectTypeKey': 'software',
#  'fields.project.self': 'https://issues.redhat.com/rest/api/2/project/12322421',
#  'fields.reporter.active': True,
#  'fields.reporter.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#  'fields.reporter.displayName': 'Edoardo Vacchi',
#  'fields.reporter.emailAddress': 'evacchi@redhat.com',
#  'fields.reporter.key': 'evacchi',
#  'fields.reporter.name': 'evacchi',
#  'fields.reporter.self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#  'fields.reporter.timeZone': 'Europe/Rome',
#  'fields.resolution.description': 'Work has been completed on this issue.',
#  'fields.resolution.id': '1',
#  'fields.resolution.name': 'Done',
#  'fields.resolution.self': 'https://issues.redhat.com/rest/api/2/resolution/1',
#  'fields.resolutiondate': '2022-02-21T10:44:47.000+0000',
#  'fields.status.description': 'For teams with longer stakeholder feedback loops (multiple days before they typically respond), this status can be used to indicate the work is done and deployed, but still awaiting sign-off from the requester(s). It is different from Release Pending because the work has been deployed. This is meant for help-desk style interactions, not product development.',
#  'fields.status.iconUrl': 'https://issues.redhat.com/images/icons/statuses/resolved.png',
#  'fields.status.id': '5',
#  'fields.status.name': 'Resolved',
#  'fields.status.self': 'https://issues.redhat.com/rest/api/2/status/5',
#  'fields.status.statusCategory.colorName': 'green',
#  'fields.status.statusCategory.id': 3,
#  'fields.status.statusCategory.key': 'done',
#  'fields.status.statusCategory.name': 'Done',
#  'fields.status.statusCategory.self': 'https://issues.redhat.com/rest/api/2/statuscategory/3',
#  'fields.subtasks': [],
#  'fields.summary': 'Rule Codegen REST refactor',
#  'fields.timeestimate': None,
#  'fields.timeoriginalestimate': None,
#  'fields.timespent': None,
#  'fields.updated': '2022-02-21T10:45:00.000+0000',
#  'fields.versions': [],
#  'fields.votes.hasVoted': False,
#  'fields.votes.self': 'https://issues.redhat.com/rest/api/2/issue/KOGITO-6675/votes',
#  'fields.votes.votes': 0,
#  'fields.watches.isWatching': False,
#  'fields.watches.self': 'https://issues.redhat.com/rest/api/2/issue/KOGITO-6675/watchers',
#  'fields.watches.watchCount': 0,
#  'fields.worklog.maxResults': 20,
#  'fields.worklog.startAt': 0,
#  'fields.worklog.total': 0,
#  'fields.worklog.worklogs': [],
#  'fields.workratio': -1,
#  'id': '14457621',
#  'key': 'KOGITO-6675',
#  'self': 'https://issues.redhat.com/rest/agile/1.0/issue/14457621'}

# %%
issue_result = pd.DataFrame()

for i in issue_df.index:
   issue_df_1 = issue_df.iloc[i].apply(pd.Series)
   issue_df_1['board_id'] = board_df['id'][i]
   frame = [issue_result, issue_df_1]
   issue_result = pd.concat(frame)

issue_result = issue_result.reset_index()
issue_result = issue_result.drop(columns=['index'])

# %%
#Only select issues that have story points
issue_result = issue_result[issue_result['fields.customfield_12310243'].notna()]
issue_result.head()
# Out:
#                                                expand        id  \
# 2   operations,versionedRepresentations,editmeta,c...  14438475
# 10  operations,versionedRepresentations,editmeta,c...  14481687
# 11  operations,versionedRepresentations,editmeta,c...  14481688
# 12  operations,versionedRepresentations,editmeta,c...  14489650
# 15  operations,versionedRepresentations,editmeta,c...  14238297
#
#                                                  self          key  \
# 2   https://issues.redhat.com/rest/agile/1.0/issue...  DROOLS-6782
# 10  https://issues.redhat.com/rest/agile/1.0/issue...  DROOLS-6826
# 11  https://issues.redhat.com/rest/agile/1.0/issue...  KOGITO-6771
# 12  https://issues.redhat.com/rest/agile/1.0/issue...  DROOLS-6834
# 15  https://issues.redhat.com/rest/agile/1.0/issue...  KOGITO-5850
#
#                                 fields.issuetype.self fields.issuetype.id  \
# 2   https://issues.redhat.com/rest/api/2/issuetype/17                  17
# 10   https://issues.redhat.com/rest/api/2/issuetype/3                   3
# 11  https://issues.redhat.com/rest/api/2/issuetype/13                  13
# 12   https://issues.redhat.com/rest/api/2/issuetype/1                   1
# 15  https://issues.redhat.com/rest/api/2/issuetype/17                  17
#
#                          fields.issuetype.description  \
# 2   Created by Jira Software - do not edit or dele...
# 10                      A task that needs to be done.
# 11  An enhancement or refactoring of existing func...
# 12  A problem which impairs or prevents the functi...
# 15  Created by Jira Software - do not edit or dele...
#
#                              fields.issuetype.iconUrl fields.issuetype.name  \
# 2   https://issues.redhat.com/secure/viewavatar?si...                 Story
# 10  https://issues.redhat.com/secure/viewavatar?si...                  Task
# 11  https://issues.redhat.com/secure/viewavatar?si...           Enhancement
# 12  https://issues.redhat.com/secure/viewavatar?si...                   Bug
# 15  https://issues.redhat.com/secure/viewavatar?si...                 Story
#
#    fields.issuetype.subtask  ...  fields.timetracking.timeSpent  \
# 2                     False  ...                            NaN
# 10                    False  ...                            NaN
# 11                    False  ...                            NaN
# 12                    False  ...                            NaN
# 15                    False  ...                            NaN
#
#    fields.timetracking.timeSpentSeconds fields.customfield_12317338  \
# 2                                   NaN                         NaN
# 10                                  NaN                         NaN
# 11                                  NaN                         NaN
# 12                                  NaN                         NaN
# 15                                  NaN                         NaN
#
#    fields.customfield_12314440 fields.customfield_12310022  \
# 2                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 15                         NaN                         NaN
#
#    fields.customfield_12310021 fields.customfield_12310071  \
# 2                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 15                         NaN                         NaN
#
#    fields.customfield_12316042 fields.customfield_12316043 fields.priority
# 2                          NaN                         NaN             NaN
# 10                         NaN                         NaN             NaN
# 11                         NaN                         NaN             NaN
# 12                         NaN                         NaN             NaN
# 15                         NaN                         NaN             NaN
#
# [5 rows x 336 columns]

# %%
#Check the dataframe shape
issue_result.shape
# Out:
# (3120, 336)

# %%
#Save as csv file
issue_result.to_csv('KOGITO_issues.csv')
