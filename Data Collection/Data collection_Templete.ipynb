# %% [markdown]
# ## Reminder
# Please use Python 3.10 or Python 3.9 to run the code. Otherwise the pd.json_normalize function may not work
#
# ## Data collection idea
# * Use "Board" dataset as a bridge to link both "Sprint" and "Issue" URL and data table.
# * For spint and issues table, attach create a new column and store board id in it, so that we can know which board does the data comes from.
#
# ### Steps:
# #### Board:
# 1. Retrieve board from API URL: {Base URL of your project}/rest/agile/1.0/board?projectKeyOrId={projectKey}
# * Base URL: check the excel file on OneDrive
# * ProjectKey: Search the project name on corresponding platform (RedHat or Apache) -> Under the "Project" category
# 2. Request data by using GET method and get the json output.
# 3. Transform data from JSON format to the pandas dataframe.
# 4. Filter the board type (type == 'scrum') and reset the index
# 5. Store board_id for future analysis
# 6. Save as csv file so that we don't have to rerun the code every time.
#
# #### Sprint:
# 1. Loop pre-stored board_id to get all sprint and store them into an empty list (as computation cost of expand a cost is much smaller than expand a pandas dataframe).
# 2. Normalize the list and we will get a dataframe (called df_initalResult) whose records are all nested.
# 3. For each row, we want to flatten the data into a normal data record type. Therefore, we create a new empty dataframe (df_finalResult) first then loop through the "df_initalResult" by using its index and save each records in a temp dataframe (df_temp). Then concat df_finalResult and df_temp, after which, we can get a complete datasets that contains all records.
# 4. Save as csv file.
#
# #### Issues:
# 1. Similar as Sprint method. The thing is that we only want the issues that have story points, which is stored in customer fields (check column name in excel file). Therefore, after we getting all issues, we need to filter out the issues that have story points.
# 2. Save as csv file.

# %%
import requests
from requests.auth import HTTPBasicAuth
import json
import base64
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Your Project Name

# %%
#For RedHat, just replace your token and keep string "Bearer"
auth = "Bearer YourToken"

#For Apache, you can use same method as RedHat, if it doesn't work, please try the following
auth=HTTPBasicAuth("YourUserName", "YourPassword")
# Also for Apache, please use following format to retrieve data.
url = "xxxxxx"
headers = {
   "Accept": "application/json"
}

payload = {
   "maxResults":50 
}

board = requests.request("GET",url,headers=headers,auth=auth, params=payload).json()

# %% [markdown]
# ### Board

# %%
# Replace BaseURL and project key with your own project
board_url = '{BaseURL}/rest/agile/1.0/board?projectKeyOrId={ProjectKey}'

headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}

payload = {
   "maxResults":50 #100, 20
}

# Request data by using GET method and directly get the json output
board = requests.request("GET",board_url,headers=headers, params=payload).json()

# As we only intreseted in the "values" in the board, so we only normalize the board['values']
board_df = pd.json_normalize(board['values'])

# Filter the scrum board type and maintain the pd dataframe formate
board_df = board_df[board_df['type']=='scrum']

# Reset the index for the future convience.
board_df = board_df.reset_index()

# Store the board id into variable board_id
board_id = board_df['id']

#Save the df as csv file. Use your project name to define the file name
board_df.to_csv('YourProjectName_board.csv')

# %% [markdown]
# #### Sprint

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}


payload_sprint = {
'maxResults':2000  #Retrieve at most 2000 records, can be modified based on your own project
}

list1 = [] 

# Loop through the required board, and store the records into the empty list1
for i in board_id:
   sprint_url = 'https://issues.redhat.com/rest/agile/1.0/board/' + f'{i}' + '/sprint'
   sprint = requests.request("GET",sprint_url ,headers=headers, params=payload_sprint).json()
   try:
      list1.append(sprint['values'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
sprint_df = pd.json_normalize(list1)
sprint_df.head()
# Out:
#                                                   0   \
# 0  {'id': 5140, 'self': 'https://issues.redhat.co...
# 1  {'id': 3262, 'self': 'https://issues.redhat.co...
# 2  {'id': 3222, 'self': 'https://issues.redhat.co...
# 3  {'id': 8166, 'self': 'https://issues.redhat.co...
# 4  {'id': 4660, 'self': 'https://issues.redhat.co...
#
#                                                   1   \
# 0  {'id': 5408, 'self': 'https://issues.redhat.co...
# 1  {'id': 3342, 'self': 'https://issues.redhat.co...
# 2  {'id': 3352, 'self': 'https://issues.redhat.co...
# 3  {'id': 8514, 'self': 'https://issues.redhat.co...
# 4  {'id': 5140, 'self': 'https://issues.redhat.co...
#
#                                                   2   \
# 0  {'id': 5504, 'self': 'https://issues.redhat.co...
# 1  {'id': 3352, 'self': 'https://issues.redhat.co...
# 2  {'id': 3362, 'self': 'https://issues.redhat.co...
# 3  {'id': 8516, 'self': 'https://issues.redhat.co...
# 4  {'id': 5214, 'self': 'https://issues.redhat.co...
#
#                                                   3   \
# 0  {'id': 6024, 'self': 'https://issues.redhat.co...
# 1  {'id': 3362, 'self': 'https://issues.redhat.co...
# 2  {'id': 3372, 'self': 'https://issues.redhat.co...
# 3  {'id': 8518, 'self': 'https://issues.redhat.co...
# 4  {'id': 5408, 'self': 'https://issues.redhat.co...
#
#                                                   4   \
# 0  {'id': 6126, 'self': 'https://issues.redhat.co...
# 1  {'id': 3372, 'self': 'https://issues.redhat.co...
# 2  {'id': 3382, 'self': 'https://issues.redhat.co...
# 3  {'id': 8520, 'self': 'https://issues.redhat.co...
# 4  {'id': 5504, 'self': 'https://issues.redhat.co...
#
#                                                   5   \
# 0  {'id': 6146, 'self': 'https://issues.redhat.co...
# 1  {'id': 3382, 'self': 'https://issues.redhat.co...
# 2  {'id': 3392, 'self': 'https://issues.redhat.co...
# 3  {'id': 8932, 'self': 'https://issues.redhat.co...
# 4  {'id': 5622, 'self': 'https://issues.redhat.co...
#
#                                                   6   \
# 0  {'id': 6180, 'self': 'https://issues.redhat.co...
# 1  {'id': 3392, 'self': 'https://issues.redhat.co...
# 2  {'id': 4848, 'self': 'https://issues.redhat.co...
# 3  {'id': 8934, 'self': 'https://issues.redhat.co...
# 4  {'id': 5644, 'self': 'https://issues.redhat.co...
#
#                                                   7   \
# 0  {'id': 6257, 'self': 'https://issues.redhat.co...
# 1  {'id': 3962, 'self': 'https://issues.redhat.co...
# 2  {'id': 4660, 'self': 'https://issues.redhat.co...
# 3  {'id': 8936, 'self': 'https://issues.redhat.co...
# 4  {'id': 5646, 'self': 'https://issues.redhat.co...
#
#                                                   8   \
# 0  {'id': 6287, 'self': 'https://issues.redhat.co...
# 1  {'id': 4462, 'self': 'https://issues.redhat.co...
# 2  {'id': 4412, 'self': 'https://issues.redhat.co...
# 3  {'id': 8938, 'self': 'https://issues.redhat.co...
# 4  {'id': 5712, 'self': 'https://issues.redhat.co...
#
#                                                   9   ...  \
# 0  {'id': 6363, 'self': 'https://issues.redhat.co...  ...
# 1  {'id': 4520, 'self': 'https://issues.redhat.co...  ...
# 2  {'id': 4896, 'self': 'https://issues.redhat.co...  ...
# 3  {'id': 9122, 'self': 'https://issues.redhat.co...  ...
# 4  {'id': 5932, 'self': 'https://issues.redhat.co...  ...
#
#                                                   40  \
# 0  {'id': 7764, 'self': 'https://issues.redhat.co...
# 1  {'id': 38868, 'self': 'https://issues.redhat.c...
# 2  {'id': 6287, 'self': 'https://issues.redhat.co...
# 3  {'id': 25171, 'self': 'https://issues.redhat.c...
# 4  {'id': 6895, 'self': 'https://issues.redhat.co...
#
#                                                   41  \
# 0  {'id': 7912, 'self': 'https://issues.redhat.co...
# 1  {'id': 38869, 'self': 'https://issues.redhat.c...
# 2  {'id': 6363, 'self': 'https://issues.redhat.co...
# 3  {'id': 25172, 'self': 'https://issues.redhat.c...
# 4  {'id': 7241, 'self': 'https://issues.redhat.co...
#
#                                                   42  \
# 0  {'id': 7914, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6365, 'self': 'https://issues.redhat.co...
# 3  {'id': 25173, 'self': 'https://issues.redhat.c...
# 4  {'id': 6915, 'self': 'https://issues.redhat.co...
#
#                                                   43  \
# 0  {'id': 7916, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6377, 'self': 'https://issues.redhat.co...
# 3  {'id': 25174, 'self': 'https://issues.redhat.c...
# 4  {'id': 6979, 'self': 'https://issues.redhat.co...
#
#                                                   44  \
# 0  {'id': 7918, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6387, 'self': 'https://issues.redhat.co...
# 3  {'id': 25175, 'self': 'https://issues.redhat.c...
# 4  {'id': 7289, 'self': 'https://issues.redhat.co...
#
#                                                   45  \
# 0  {'id': 8160, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6627, 'self': 'https://issues.redhat.co...
# 3  {'id': 38867, 'self': 'https://issues.redhat.c...
# 4  {'id': 7061, 'self': 'https://issues.redhat.co...
#
#                                                   46  \
# 0  {'id': 8158, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6633, 'self': 'https://issues.redhat.co...
# 3  {'id': 38868, 'self': 'https://issues.redhat.c...
# 4  {'id': 7173, 'self': 'https://issues.redhat.co...
#
#                                                   47  \
# 0  {'id': 8162, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6531, 'self': 'https://issues.redhat.co...
# 3  {'id': 38869, 'self': 'https://issues.redhat.c...
# 4  {'id': 7187, 'self': 'https://issues.redhat.co...
#
#                                                   48  \
# 0  {'id': 8164, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6851, 'self': 'https://issues.redhat.co...
# 3  {'id': 40100, 'self': 'https://issues.redhat.c...
# 4  {'id': 7189, 'self': 'https://issues.redhat.co...
#
#                                                   49
# 0  {'id': 8166, 'self': 'https://issues.redhat.co...
# 1                                               None
# 2  {'id': 6725, 'self': 'https://issues.redhat.co...
# 3  {'id': 40625, 'self': 'https://issues.redhat.c...
# 4  {'id': 7191, 'self': 'https://issues.redhat.co...
#
# [5 rows x 50 columns]

# %%
#Create an empty dataframe
sprint_result = pd.DataFrame()
sprint_result.head()

# sprint_df.index is the row number. For each row, we need to flatten the records and store them into a dataframe. Our goal is to flatten all these record and generate a single dataframe.
for i in sprint_df.index:
   # Flatten records in a row based on row index
   sprint_df_1 = sprint_df.iloc[i].apply(pd.Series) 
   # Attach corresponding board_id
   sprint_df_1['board_id'] = board_df['id'][i]
   # Create a list called "frame" to tell python we want to contact two dataframs together -- sprint_result and sprint_df_1
   frame = [sprint_result, sprint_df_1]
   #Contact two dataframes
   sprint_result = pd.concat(frame)

# %%
# Filter the sprint that totally empty
sprint_result = sprint_result[sprint_result['id'].notna()]
sprint_result.head()
# Out:
#        id                                               self   state  \
# 0  5140.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 1  5408.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 2  5504.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 3  6024.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 4  6126.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
#
#                         name                 startDate  \
# 0  GSSP_6.4 Sprint- 3-31 Aug  2016-08-03T08:17:20.067Z
# 1            November Sprint  2016-11-03T23:46:23.504Z
# 2            December Sprint  2016-12-01T13:10:38.253Z
# 3            May 2017 Sprint  2017-05-04T20:52:59.038Z
# 4            2017 Week 22-23  2017-05-29T04:00:00.000Z
#
#                     endDate              completeDate  \
# 0  2016-08-31T12:17:00.000Z  2016-09-06T21:40:41.465Z
# 1  2016-12-02T00:46:00.000Z  2016-11-30T13:29:23.663Z
# 2  2016-12-29T13:10:00.000Z  2017-01-02T09:17:34.512Z
# 3  2017-05-29T20:52:00.000Z  2017-06-07T11:15:40.285Z
# 4  2017-06-12T03:59:00.000Z  2017-06-12T13:25:18.855Z
#
#               activatedDate  originBoardId goal  board_id
# 0  2016-08-03T08:17:20.067Z         3548.0  NaN      4532
# 1  2016-11-03T23:46:23.504Z         3548.0  NaN      4532
# 2  2016-12-01T13:10:38.253Z         3548.0  NaN      4532
# 3  2017-05-04T20:52:59.038Z         3548.0  NaN      4532
# 4  2017-05-29T04:00:00.000Z         3838.0  NaN      4532

# %%
# Reset the index
sprint_result = sprint_result.reset_index()
# Drop the origianl index column
sprint_result = sprint_result.drop(columns=['index'])
sprint_result.head()
# Out:
#        id                                               self   state  \
# 0  5140.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 1  5408.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 2  5504.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 3  6024.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
# 4  6126.0  https://issues.redhat.com/rest/agile/1.0/sprin...  closed
#
#                         name                 startDate  \
# 0  GSSP_6.4 Sprint- 3-31 Aug  2016-08-03T08:17:20.067Z
# 1            November Sprint  2016-11-03T23:46:23.504Z
# 2            December Sprint  2016-12-01T13:10:38.253Z
# 3            May 2017 Sprint  2017-05-04T20:52:59.038Z
# 4            2017 Week 22-23  2017-05-29T04:00:00.000Z
#
#                     endDate              completeDate  \
# 0  2016-08-31T12:17:00.000Z  2016-09-06T21:40:41.465Z
# 1  2016-12-02T00:46:00.000Z  2016-11-30T13:29:23.663Z
# 2  2016-12-29T13:10:00.000Z  2017-01-02T09:17:34.512Z
# 3  2017-05-29T20:52:00.000Z  2017-06-07T11:15:40.285Z
# 4  2017-06-12T03:59:00.000Z  2017-06-12T13:25:18.855Z
#
#               activatedDate  originBoardId goal  board_id
# 0  2016-08-03T08:17:20.067Z         3548.0  NaN      4532
# 1  2016-11-03T23:46:23.504Z         3548.0  NaN      4532
# 2  2016-12-01T13:10:38.253Z         3548.0  NaN      4532
# 3  2017-05-04T20:52:59.038Z         3548.0  NaN      4532
# 4  2017-05-29T04:00:00.000Z         3838.0  NaN      4532

# %%
# Save as csv file
sprint_result.to_csv('YourProjectName_sprint.csv')

# %% [markdown]
# #### Issues

# %%
headers = {
   "Content-Type": "application/json",
   "Authorization": auth,  
}

payload_issues = {
'maxResults':3000
}

list1 = []
# Loop through the required board, and store the records into the empty list1
for i in board_id:
   issues_url = 'https://issues.redhat.com/rest/agile/1.0/board/' + f'{i}' + '/issue'
   issues = requests.request("GET",issues_url ,headers=headers, params=payload_issues).json()
   try:
      list1.append(issues['issues'])
   except:
      pass

# %%
# Normalize the list and get the inital dataframe, whose record are nested.
issue_df = pd.json_normalize(list1)
issue_df.head()
# Out:
#                                                  0    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  1    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  2    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  3    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  4    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  5    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  6    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  7    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  8    \
# 0  {'expand': 'operations,versionedRepresentation...
# 1  {'expand': 'operations,versionedRepresentation...
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  9    ...  \
# 0  {'expand': 'operations,versionedRepresentation...  ...
# 1  {'expand': 'operations,versionedRepresentation...  ...
# 2  {'expand': 'operations,versionedRepresentation...  ...
# 3  {'expand': 'operations,versionedRepresentation...  ...
# 4  {'expand': 'operations,versionedRepresentation...  ...
#
#                                                  990  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  991  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  992  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  993  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  994  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  995  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  996  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  997  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  998  \
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
#                                                  999
# 0  {'expand': 'operations,versionedRepresentation...
# 1                                               None
# 2  {'expand': 'operations,versionedRepresentation...
# 3  {'expand': 'operations,versionedRepresentation...
# 4  {'expand': 'operations,versionedRepresentation...
#
# [5 rows x 1000 columns]

# %%
#Check a single record content
issue_df.iloc[0][0]
# Out:
# {'expand': 'operations,versionedRepresentations,editmeta,changelog,renderedFields',
#  'id': '13429632',
#  'self': 'https://issues.redhat.com/rest/agile/1.0/issue/13429632',
#  'key': 'BXMSDOC-8068',
#  'fields.issuetype.self': 'https://issues.redhat.com/rest/api/2/issuetype/3',
#  'fields.issuetype.id': '3',
#  'fields.issuetype.description': 'A task that needs to be done.',
#  'fields.issuetype.iconUrl': 'https://issues.redhat.com/secure/viewavatar?size=xsmall&avatarId=13278&avatarType=issuetype',
#  'fields.issuetype.name': 'Task',
#  'fields.issuetype.subtask': False,
#  'fields.issuetype.avatarId': 13278,
#  'fields.customfield_12318341': None,
#  'fields.timespent': None,
#  'fields.customfield_12320940': None,
#  'fields.project.self': 'https://issues.redhat.com/rest/api/2/project/12316327',
#  'fields.project.id': '12316327',
#  'fields.project.key': 'BXMSDOC',
#  'fields.project.name': 'BxMS Documentation',
#  'fields.project.projectTypeKey': 'software',
#  'fields.project.avatarUrls.48x48': 'https://issues.redhat.com/secure/projectavatar?pid=12316327&avatarId=10011',
#  'fields.project.avatarUrls.24x24': 'https://issues.redhat.com/secure/projectavatar?size=small&pid=12316327&avatarId=10011',
#  'fields.project.avatarUrls.16x16': 'https://issues.redhat.com/secure/projectavatar?size=xsmall&pid=12316327&avatarId=10011',
#  'fields.project.avatarUrls.32x32': 'https://issues.redhat.com/secure/projectavatar?size=medium&pid=12316327&avatarId=10011',
#  'fields.fixVersions': [],
#  'fields.customfield_12320944': None,
#  'fields.aggregatetimespent': None,
#  'fields.resolution.self': 'https://issues.redhat.com/rest/api/2/resolution/1',
#  'fields.resolution.id': '1',
#  'fields.resolution.description': 'Work has been completed on this issue.',
#  'fields.resolution.name': 'Done',
#  'fields.customfield_12310220': None,
#  'fields.customfield_12312442': None,
#  'fields.customfield_12314740': '{summaryBean=com.atlassian.jira.plugin.devstatus.rest.SummaryBean@17f02867[summary={pullrequest=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@90145a1[overall=PullRequestOverallBean{stateCount=1, state=\'MERGED\', details=PullRequestOverallDetails{openCount=0, mergedCount=1, declinedCount=1}},byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@7eb16424[count=1,name=GitHub]}], build=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@7d1e1a1e[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BuildOverallBean@18d0669f[failedBuildCount=0,successfulBuildCount=0,unknownBuildCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], review=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@56d87106[overall=com.atlassian.jira.plugin.devstatus.summary.beans.ReviewsOverallBean@233dafbd[stateCount=0,state=<null>,dueDate=<null>,overDue=false,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], deployment-environment=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@2e7e8f2e[overall=com.atlassian.jira.plugin.devstatus.summary.beans.DeploymentOverallBean@3581e0e0[topEnvironments=[],showProjects=false,successfulCount=0,count=0,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={}], repository=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@2044e717[overall=com.atlassian.jira.plugin.devstatus.summary.beans.CommitOverallBean@6ecae4e5[count=1,lastUpdated=2021-09-09T15:14:12.000+0000,lastUpdatedTimestamp=2021-09-09T15:14:12.000Z],byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@349701ed[count=1,name=GitHub]}], branch=com.atlassian.jira.plugin.devstatus.rest.SummaryItemBean@eab717f[overall=com.atlassian.jira.plugin.devstatus.summary.beans.BranchOverallBean@9d053e2[count=2,lastUpdated=<null>,lastUpdatedTimestamp=<null>],byInstanceType={github=com.atlassian.jira.plugin.devstatus.summary.beans.ObjectByInstanceTypeBean@308473f1[count=2,name=GitHub]}]},errors=[],configErrors=[]], devSummaryJson={"cachedValue":{"errors":[],"configErrors":[],"summary":{"pullrequest":{"overall":{"count":1,"lastUpdated":"2021-09-09T15:14:12.000+0000","stateCount":1,"state":"MERGED","details":{"openCount":0,"mergedCount":1,"declinedCount":1,"total":2},"open":false},"byInstanceType":{"github":{"count":1,"name":"GitHub"}}},"build":{"overall":{"count":0,"lastUpdated":null,"failedBuildCount":0,"successfulBuildCount":0,"unknownBuildCount":0},"byInstanceType":{}},"review":{"overall":{"count":0,"lastUpdated":null,"stateCount":0,"state":null,"dueDate":null,"overDue":false,"completed":false},"byInstanceType":{}},"deployment-environment":{"overall":{"count":0,"lastUpdated":null,"topEnvironments":[],"showProjects":false,"successfulCount":0},"byInstanceType":{}},"repository":{"overall":{"count":1,"lastUpdated":"2021-09-09T15:14:12.000+0000"},"byInstanceType":{"github":{"count":1,"name":"GitHub"}}},"branch":{"overall":{"count":2,"lastUpdated":null},"byInstanceType":{"github":{"count":2,"name":"GitHub"}}}}},"isStale":true}}',
#  'fields.resolutiondate': '2021-11-23T11:46:39.000+0000',
#  'fields.workratio': -1,
#  'fields.customfield_12317379': None,
#  'fields.customfield_12315950': None,
#  'fields.customfield_12316841': None,
#  'fields.customfield_12317338': None,
#  'fields.customfield_12310940': ['com.atlassian.greenhopper.service.sprint.Sprint@41156aa3[id=25172,rapidViewId=4036,state=CLOSED,name=2021 Week 31-33 (from Aug 2),startDate=2021-08-04T00:01:00.000Z,endDate=2021-08-22T11:59:00.000Z,completeDate=2021-08-23T10:07:55.257Z,activatedDate=2021-08-04T08:35:43.276Z,sequence=25172,goal=,autoStartStop=false]',
#   'com.atlassian.greenhopper.service.sprint.Sprint@49e398f9[id=25173,rapidViewId=4036,state=CLOSED,name=2021 Week 34-36 (from Aug 23),startDate=2021-08-25T00:01:00.000Z,endDate=2021-09-12T23:59:00.000Z,completeDate=2021-09-13T09:55:40.030Z,activatedDate=2021-08-25T09:48:09.715Z,sequence=25173,goal=,autoStartStop=false]',
#   'com.atlassian.greenhopper.service.sprint.Sprint@634da90[id=25174,rapidViewId=4036,state=CLOSED,name=2021 Week 37-39 (from Sep 13),startDate=2021-09-15T00:01:00.000Z,endDate=2021-10-03T23:59:00.000Z,completeDate=2021-10-04T11:05:26.677Z,activatedDate=2021-09-15T09:51:44.597Z,sequence=25174,goal=,autoStartStop=false]',
#   'com.atlassian.greenhopper.service.sprint.Sprint@4f6154c3[id=25175,rapidViewId=4036,state=CLOSED,name=2021 Week 40-42 (from Oct 4),startDate=2021-10-06T00:01:00.000Z,endDate=2021-10-24T23:59:00.000Z,completeDate=2021-10-25T09:46:17.376Z,activatedDate=2021-10-06T09:54:03.451Z,sequence=25175,goal=,autoStartStop=false]',
#   'com.atlassian.greenhopper.service.sprint.Sprint@25cb7ffe[id=38867,rapidViewId=4036,state=CLOSED,name=2021 Week 43-45 (from Oct 25),startDate=2021-10-27T00:01:00.000Z,endDate=2021-11-14T23:59:00.000Z,completeDate=2021-11-15T11:21:51.038Z,activatedDate=2021-10-27T09:49:03.076Z,sequence=38867,goal=,autoStartStop=false]',
#   'com.atlassian.greenhopper.service.sprint.Sprint@70ba0fee[id=38868,rapidViewId=4036,state=CLOSED,name=2021 Week 46-48 (from Nov 15),startDate=2021-11-17T00:01:00.000Z,endDate=2021-12-05T23:59:00.000Z,completeDate=2021-12-06T11:17:52.070Z,activatedDate=2021-11-17T10:55:17.966Z,sequence=38868,goal=,autoStartStop=false]'],
#  'fields.lastViewed': None,
#  'fields.watches.self': 'https://issues.redhat.com/rest/api/2/issue/BXMSDOC-8068/watchers',
#  'fields.watches.watchCount': 4,
#  'fields.watches.isWatching': False,
#  'fields.created': '2021-08-02T08:05:28.000+0000',
#  'fields.customfield_12313140': None,
#  'fields.priority.self': 'https://issues.redhat.com/rest/api/2/priority/3',
#  'fields.priority.iconUrl': 'https://issues.redhat.com/images/icons/priorities/major.svg',
#  'fields.priority.name': 'Major',
#  'fields.priority.id': '3',
#  'fields.labels': [],
#  'fields.customfield_12311244': None,
#  'fields.customfield_12311640': None,
#  'fields.customfield_12311245': None,
#  'fields.customfield_12311641': None,
#  'fields.customfield_12315841': None,
#  'fields.customfield_12311242': None,
#  'fields.customfield_12315840': None,
#  'fields.customfield_12311243': None,
#  'fields.customfield_12311240': None,
#  'fields.aggregatetimeoriginalestimate': None,
#  'fields.timeestimate': None,
#  'fields.versions': [],
#  'fields.customfield_12311241': None,
#  'fields.customfield_12310031': [{'self': 'https://issues.redhat.com/rest/api/2/customFieldOption/10015',
#    'value': 'Documentation (Ref Guide, User Guide, etc.)',
#    'id': '10015',
#    'disabled': False}],
#  'fields.issuelinks': [{'id': '13244177',
#    'self': 'https://issues.redhat.com/rest/api/2/issueLink/13244177',
#    'type': {'id': '12310001',
#     'name': 'Related',
#     'inward': 'is related to',
#     'outward': 'relates to',
#     'self': 'https://issues.redhat.com/rest/api/2/issueLinkType/12310001'},
#    'outwardIssue': {'id': '13429631',
#     'key': 'KOGITO-5626',
#     'self': 'https://issues.redhat.com/rest/api/2/issue/13429631',
#     'fields': {'summary': 'Verify alternative workflow for native image building and deployment (Mandrel)',
#      'status': {'self': 'https://issues.redhat.com/rest/api/2/status/5',
#       'description': 'For teams with longer stakeholder feedback loops (multiple days before they typically respond), this status can be used to indicate the work is done and deployed, but still awaiting sign-off from the requester(s). It is different from Release Pending because the work has been deployed. This is meant for help-desk style interactions, not product development.',
#       'iconUrl': 'https://issues.redhat.com/images/icons/statuses/resolved.png',
#       'name': 'Resolved',
#       'id': '5',
#       'statusCategory': {'self': 'https://issues.redhat.com/rest/api/2/statuscategory/3',
#        'id': 3,
#        'key': 'done',
#        'colorName': 'green',
#        'name': 'Done'}},
#      'priority': {'self': 'https://issues.redhat.com/rest/api/2/priority/3',
#       'iconUrl': 'https://issues.redhat.com/images/icons/priorities/major.svg',
#       'name': 'Major',
#       'id': '3'},
#      'issuetype': {'self': 'https://issues.redhat.com/rest/api/2/issuetype/3',
#       'id': '3',
#       'description': 'A task that needs to be done.',
#       'iconUrl': 'https://issues.redhat.com/secure/viewavatar?size=xsmall&avatarId=13278&avatarType=issuetype',
#       'name': 'Task',
#       'subtask': False,
#       'avatarId': 13278}}}}],
#  'fields.assignee.self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#  'fields.assignee.name': 'csherrar',
#  'fields.assignee.key': 'csherrar',
#  'fields.assignee.emailAddress': 'csherrar@redhat.com',
#  'fields.assignee.avatarUrls.48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#  'fields.assignee.avatarUrls.24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#  'fields.assignee.avatarUrls.16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#  'fields.assignee.avatarUrls.32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32',
#  'fields.assignee.displayName': 'Clifton Sherrard',
#  'fields.assignee.active': True,
#  'fields.assignee.timeZone': 'Europe/Dublin',
#  'fields.updated': '2021-11-23T11:46:39.000+0000',
#  'fields.customfield_12313942': None,
#  'fields.customfield_12311840': None,
#  'fields.customfield_12313941': None,
#  'fields.status.self': 'https://issues.redhat.com/rest/api/2/status/5',
#  'fields.status.description': 'For teams with longer stakeholder feedback loops (multiple days before they typically respond), this status can be used to indicate the work is done and deployed, but still awaiting sign-off from the requester(s). It is different from Release Pending because the work has been deployed. This is meant for help-desk style interactions, not product development.',
#  'fields.status.iconUrl': 'https://issues.redhat.com/images/icons/statuses/resolved.png',
#  'fields.status.name': 'Resolved',
#  'fields.status.id': '5',
#  'fields.status.statusCategory.self': 'https://issues.redhat.com/rest/api/2/statuscategory/3',
#  'fields.status.statusCategory.id': 3,
#  'fields.status.statusCategory.key': 'done',
#  'fields.status.statusCategory.colorName': 'green',
#  'fields.status.statusCategory.name': 'Done',
#  'fields.components': [],
#  'fields.customfield_12317275': None,
#  'fields.customfield_12317276': None,
#  'fields.timeoriginalestimate': None,
#  'fields.customfield_12310080': None,
#  'fields.description': 'An alternative workflow was proposed to native image creation and deployment.\r\nIn such an alternative workflow:\r\n\r\n1) does not use our s2i flow (at least not for the full process)\r\n2) does not use the kogito cli\r\n3) does not depend on our operator\r\n\r\ninstead:\r\n\r\n1) users will create a native image locally using the Quarkus builder image and \r\n2) will push the native image to the cluster using `oc` or other similar flow (e.g. what about Kube?)\r\n\r\nThus:\r\n\r\nit is necessary to verify one such flow works and update the documentation accordingly\r\n',
#  'fields.customfield_12314040': None,
#  'fields.customfield_12320640': None,
#  'fields.archiveddate': None,
#  'fields.customfield_12310440': None,
#  'fields.customfield_12310120': None,
#  'fields.customfield_12310243': 7.0,
#  'fields.attachment': [],
#  'fields.aggregatetimeestimate': None,
#  'fields.flagged': False,
#  'fields.customfield_12314440': None,
#  'fields.customfield_12316542.self': 'https://issues.redhat.com/rest/api/2/customFieldOption/14655',
#  'fields.customfield_12316542.value': 'False',
#  'fields.customfield_12316542.id': '14655',
#  'fields.customfield_12316542.disabled': False,
#  'fields.customfield_12316543.self': 'https://issues.redhat.com/rest/api/2/customFieldOption/14657',
#  'fields.customfield_12316543.value': 'False',
#  'fields.customfield_12316543.id': '14657',
#  'fields.customfield_12316543.disabled': False,
#  'fields.customfield_12317313': 'Undefined',
#  'fields.customfield_12316544': None,
#  'fields.customfield_12310840': '9223372036854775807',
#  'fields.summary': 'Kogito: Document alternative workflow for native image building and deployment (Mandrel) BAPL-1822',
#  'fields.creator.self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#  'fields.creator.name': 'evacchi',
#  'fields.creator.key': 'evacchi',
#  'fields.creator.emailAddress': 'evacchi@redhat.com',
#  'fields.creator.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#  'fields.creator.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409',
#  'fields.creator.displayName': 'Edoardo Vacchi',
#  'fields.creator.active': True,
#  'fields.creator.timeZone': 'Europe/Rome',
#  'fields.subtasks': [],
#  'fields.reporter.self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#  'fields.reporter.name': 'evacchi',
#  'fields.reporter.key': 'evacchi',
#  'fields.reporter.emailAddress': 'evacchi@redhat.com',
#  'fields.reporter.avatarUrls.48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.avatarUrls.32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409',
#  'fields.reporter.displayName': 'Edoardo Vacchi',
#  'fields.reporter.active': True,
#  'fields.reporter.timeZone': 'Europe/Rome',
#  'fields.customfield_12310092': None,
#  'fields.aggregateprogress.progress': 0,
#  'fields.aggregateprogress.total': 0,
#  'fields.customfield_12315944': None,
#  'fields.customfield_12310211': None,
#  'fields.customfield_12313441': '',
#  'fields.customfield_12315740': None,
#  'fields.customfield_12315542': None,
#  'fields.customfield_12313440': '',
#  'fields.customfield_12313240': None,
#  'fields.duedate': None,
#  'fields.customfield_12311140': 'BXMSDOC-7860',
#  'fields.closedSprints': [{'id': 38867,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/38867',
#    'state': 'closed',
#    'name': '2021 Week 43-45 (from Oct 25)',
#    'startDate': '2021-10-27T00:01:00.000Z',
#    'endDate': '2021-11-14T23:59:00.000Z',
#    'completeDate': '2021-11-15T11:21:51.038Z',
#    'activatedDate': '2021-10-27T09:49:03.076Z',
#    'originBoardId': 4036,
#    'goal': ''},
#   {'id': 25172,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/25172',
#    'state': 'closed',
#    'name': '2021 Week 31-33 (from Aug 2)',
#    'startDate': '2021-08-04T00:01:00.000Z',
#    'endDate': '2021-08-22T11:59:00.000Z',
#    'completeDate': '2021-08-23T10:07:55.257Z',
#    'activatedDate': '2021-08-04T08:35:43.276Z',
#    'originBoardId': 4036,
#    'goal': ''},
#   {'id': 38868,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/38868',
#    'state': 'closed',
#    'name': '2021 Week 46-48 (from Nov 15)',
#    'startDate': '2021-11-17T00:01:00.000Z',
#    'endDate': '2021-12-05T23:59:00.000Z',
#    'completeDate': '2021-12-06T11:17:52.070Z',
#    'activatedDate': '2021-11-17T10:55:17.966Z',
#    'originBoardId': 4036,
#    'goal': ''},
#   {'id': 25173,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/25173',
#    'state': 'closed',
#    'name': '2021 Week 34-36 (from Aug 23)',
#    'startDate': '2021-08-25T00:01:00.000Z',
#    'endDate': '2021-09-12T23:59:00.000Z',
#    'completeDate': '2021-09-13T09:55:40.030Z',
#    'activatedDate': '2021-08-25T09:48:09.715Z',
#    'originBoardId': 4036,
#    'goal': ''},
#   {'id': 25174,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/25174',
#    'state': 'closed',
#    'name': '2021 Week 37-39 (from Sep 13)',
#    'startDate': '2021-09-15T00:01:00.000Z',
#    'endDate': '2021-10-03T23:59:00.000Z',
#    'completeDate': '2021-10-04T11:05:26.677Z',
#    'activatedDate': '2021-09-15T09:51:44.597Z',
#    'originBoardId': 4036,
#    'goal': ''},
#   {'id': 25175,
#    'self': 'https://issues.redhat.com/rest/agile/1.0/sprint/25175',
#    'state': 'closed',
#    'name': '2021 Week 40-42 (from Oct 4)',
#    'startDate': '2021-10-06T00:01:00.000Z',
#    'endDate': '2021-10-24T23:59:00.000Z',
#    'completeDate': '2021-10-25T09:46:17.376Z',
#    'activatedDate': '2021-10-06T09:54:03.451Z',
#    'originBoardId': 4036,
#    'goal': ''}],
#  'fields.progress.progress': 0,
#  'fields.progress.total': 0,
#  'fields.comment.comments': [{'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/16501236',
#    'id': '16501236',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=viyengar%40redhat.com',
#     'name': 'viyengar@redhat.com',
#     'key': 'vidya_iyengar',
#     'emailAddress': 'viyengar@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=vidya_iyengar&avatarId=30602',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=vidya_iyengar&avatarId=30602',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=vidya_iyengar&avatarId=30602',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=vidya_iyengar&avatarId=30602'},
#     'displayName': 'Vidya Iyengar',
#     'active': True,
#     'timeZone': 'Asia/Kolkata'},
#    'body': '[~csherrar]this is related to bapl {color:#202124}BAPL-1822. This will impact [https://access.redhat.com/documentation/en-us/red_hat_process_automation_manager/7.11/html-single/getting_started_with_red_hat_build_of_kogito_in_red_hat_process_automation_manager/index#assembly-deploying-kogito-microservices-on-openshift].{color}\r\n\r\n{color:#202124}[~hmanwani@redhat.com] fyi{color}\r\n\r\n{color:#202124}[~kaldesai] BAPL-1822 is tech preview. Will impact RN as well. Pls link BAPL-1822 to RN.{color}',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=viyengar%40redhat.com',
#     'name': 'viyengar@redhat.com',
#     'key': 'vidya_iyengar',
#     'emailAddress': 'viyengar@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=vidya_iyengar&avatarId=30602',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=vidya_iyengar&avatarId=30602',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=vidya_iyengar&avatarId=30602',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=vidya_iyengar&avatarId=30602'},
#     'displayName': 'Vidya Iyengar',
#     'active': True,
#     'timeZone': 'Asia/Kolkata'},
#    'created': '2021-08-04T14:13:22.114+0000',
#    'updated': '2021-08-04T14:13:22.114+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/16501253',
#    'id': '16501253',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'body': 'Draft PR WIP https://github.com/kiegroup/kie-docs/pull/3827',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'created': '2021-08-04T14:21:40.663+0000',
#    'updated': '2021-08-04T14:21:40.663+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/16501469',
#    'id': '16501469',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=kaldesai',
#     'name': 'kaldesai',
#     'key': 'kaldesai',
#     'emailAddress': 'kaldesai@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=kaldesai&avatarId=25406',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=kaldesai&avatarId=25406',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=kaldesai&avatarId=25406',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=kaldesai&avatarId=25406'},
#     'displayName': 'Kalyani Desai',
#     'active': True,
#     'timeZone': 'Asia/Kolkata'},
#    'body': '[~viyengar@redhat.com], thanks. I have linked it to RN.',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=kaldesai',
#     'name': 'kaldesai',
#     'key': 'kaldesai',
#     'emailAddress': 'kaldesai@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=kaldesai&avatarId=25406',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=kaldesai&avatarId=25406',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=kaldesai&avatarId=25406',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=kaldesai&avatarId=25406'},
#     'displayName': 'Kalyani Desai',
#     'active': True,
#     'timeZone': 'Asia/Kolkata'},
#    'created': '2021-08-04T14:58:49.974+0000',
#    'updated': '2021-08-04T14:58:49.974+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/16509773',
#    'id': '16509773',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'body': "[~csherrar] let me know if you'd like some changes to the PR I linked",
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'created': '2021-08-06T13:08:11.198+0000',
#    'updated': '2021-08-06T13:08:11.198+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/18794224',
#    'id': '18794224',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'body': "Thanks, Edoardo, I'll check this out and let you know soon.",
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'created': '2021-08-09T12:45:11.953+0000',
#    'updated': '2021-08-09T12:45:11.953+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/18795646',
#    'id': '18795646',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'body': '[~evacchi]\r\nHi Edoardo!\r\n\r\nSome suggestions and questions, otherwise good job! We need to check what structure is used for the Kogito docs to ensure the formatting is correct.',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'created': '2021-08-09T15:09:00.067+0000',
#    'updated': '2021-08-09T15:09:00.067+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/18795550',
#    'id': '18795550',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'body': 'wonderful, will look into those ASAP',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=evacchi',
#     'name': 'evacchi',
#     'key': 'evacchi',
#     'emailAddress': 'evacchi@redhat.com',
#     'avatarUrls': {'48x48': 'https://issues.redhat.com/secure/useravatar?ownerId=evacchi&avatarId=25409',
#      '24x24': 'https://issues.redhat.com/secure/useravatar?size=small&ownerId=evacchi&avatarId=25409',
#      '16x16': 'https://issues.redhat.com/secure/useravatar?size=xsmall&ownerId=evacchi&avatarId=25409',
#      '32x32': 'https://issues.redhat.com/secure/useravatar?size=medium&ownerId=evacchi&avatarId=25409'},
#     'displayName': 'Edoardo Vacchi',
#     'active': True,
#     'timeZone': 'Europe/Rome'},
#    'created': '2021-08-09T15:17:37.052+0000',
#    'updated': '2021-08-09T15:17:37.052+0000'},
#   {'self': 'https://issues.redhat.com/rest/api/2/issue/13429632/comment/19356715',
#    'id': '19356715',
#    'author': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'body': 'Thanks again Edoardo and Heena, marking as resolved.',
#    'updateAuthor': {'self': 'https://issues.redhat.com/rest/api/2/user?username=csherrar',
#     'name': 'csherrar',
#     'key': 'csherrar',
#     'emailAddress': 'csherrar@redhat.com',
#     'avatarUrls': {'48x48': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=48',
#      '24x24': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=24',
#      '16x16': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=16',
#      '32x32': 'https://www.gravatar.com/avatar/4d693126881fab3da1fe61bc1704fec8?d=mm&s=32'},
#     'displayName': 'Clifton Sherrard',
#     'active': True,
#     'timeZone': 'Europe/Dublin'},
#    'created': '2021-11-23T11:46:33.741+0000',
#    'updated': '2021-11-23T11:46:33.741+0000'}],
#  'fields.comment.maxResults': 8,
#  'fields.comment.total': 8,
#  'fields.comment.startAt': 0,
#  'fields.votes.self': 'https://issues.redhat.com/rest/api/2/issue/BXMSDOC-8068/votes',
#  'fields.votes.votes': 0,
#  'fields.votes.hasVoted': False,
#  'fields.worklog.startAt': 0,
#  'fields.worklog.maxResults': 20,
#  'fields.worklog.total': 0,
#  'fields.worklog.worklogs': [],
#  'fields.customfield_12319743': None,
#  'fields.customfield_12310213': None,
#  'fields.customfield_12311941': None,
#  'fields.archivedby': None,
#  'fields.customfield_12311940': '1|hxz51a:0zxzztzp1'}

# %%
issue_result = pd.DataFrame()

for i in issue_df.index:
   issue_df_1 = issue_df.iloc[i].apply(pd.Series)
   issue_df_1['board_id'] = board_df['id'][i]
   frame = [issue_result, issue_df_1]
   issue_result = pd.concat(frame)

issue_result = issue_result.reset_index()
issue_result = issue_result.drop(columns=['index'])

# %%
#Only select issues that have story points
issue_result = issue_result[issue_result['fields.customfield_12310243'].notna()]
issue_result.head()
# Out:
#                                                expand        id  \
# 0   operations,versionedRepresentations,editmeta,c...  13429632
# 56  operations,versionedRepresentations,editmeta,c...  12835934
# 60  operations,versionedRepresentations,editmeta,c...  12762960
# 76  operations,versionedRepresentations,editmeta,c...  12768016
# 78  operations,versionedRepresentations,editmeta,c...  12766916
#
#                                                  self           key  \
# 0   https://issues.redhat.com/rest/agile/1.0/issue...  BXMSDOC-8068
# 56  https://issues.redhat.com/rest/agile/1.0/issue...  BXMSDOC-4879
# 60  https://issues.redhat.com/rest/agile/1.0/issue...       AF-1456
# 76  https://issues.redhat.com/rest/agile/1.0/issue...       AF-1542
# 78  https://issues.redhat.com/rest/agile/1.0/issue...       AF-1520
#
#                                fields.issuetype.self fields.issuetype.id  \
# 0   https://issues.redhat.com/rest/api/2/issuetype/3                   3
# 56  https://issues.redhat.com/rest/api/2/issuetype/3                   3
# 60  https://issues.redhat.com/rest/api/2/issuetype/3                   3
# 76  https://issues.redhat.com/rest/api/2/issuetype/3                   3
# 78  https://issues.redhat.com/rest/api/2/issuetype/1                   1
#
#                          fields.issuetype.description  \
# 0                       A task that needs to be done.
# 56                      A task that needs to be done.
# 60                      A task that needs to be done.
# 76                      A task that needs to be done.
# 78  A problem which impairs or prevents the functi...
#
#                              fields.issuetype.iconUrl fields.issuetype.name  \
# 0   https://issues.redhat.com/secure/viewavatar?si...                  Task
# 56  https://issues.redhat.com/secure/viewavatar?si...                  Task
# 60  https://issues.redhat.com/secure/viewavatar?si...                  Task
# 76  https://issues.redhat.com/secure/viewavatar?si...                  Task
# 78  https://issues.redhat.com/secure/viewavatar?si...                   Bug
#
#    fields.issuetype.subtask  ...  \
# 0                     False  ...
# 56                    False  ...
# 60                    False  ...
# 76                    False  ...
# 78                    False  ...
#
#     fields.customfield_12316243.avatarUrls.16x16  \
# 0                                            NaN
# 56                                           NaN
# 60                                           NaN
# 76                                           NaN
# 78                                           NaN
#
#    fields.customfield_12316243.avatarUrls.32x32  \
# 0                                           NaN
# 56                                          NaN
# 60                                          NaN
# 76                                          NaN
# 78                                          NaN
#
#    fields.customfield_12316243.displayName fields.customfield_12316243.active  \
# 0                                      NaN                                NaN
# 56                                     NaN                                NaN
# 60                                     NaN                                NaN
# 76                                     NaN                                NaN
# 78                                     NaN                                NaN
#
#    fields.customfield_12316243.timeZone fields.customfield_12310022  \
# 0                                   NaN                         NaN
# 56                                  NaN                         NaN
# 60                                  NaN                         NaN
# 76                                  NaN                         NaN
# 78                                  NaN                         NaN
#
#    fields.customfield_12310021 fields.customfield_12310071  \
# 0                          NaN                         NaN
# 56                         NaN                         NaN
# 60                         NaN                         NaN
# 76                         NaN                         NaN
# 78                         NaN                         NaN
#
#    fields.customfield_12316042 fields.customfield_12316043
# 0                          NaN                         NaN
# 56                         NaN                         NaN
# 60                         NaN                         NaN
# 76                         NaN                         NaN
# 78                         NaN                         NaN
#
# [5 rows x 336 columns]

# %%
#Check the dataframe shape
issue_result.shape
# Out:
# (2610, 336)

# %%
#Save as csv file
issue_result.to_csv('YourProjectName_issues.csv')
